# %% [markdown]
# ## 1. Ground truth model
# Credits:
#
# - Author: Gabin Rousseau
# - Code source: predominantly https://github.com/Schumacher-group/cellcircuits

# %%
# Re-import necessary libraries after code environment reset
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# Re-define data
X_data = np.array([1, 2, 4, 8, 16, 32, 64, 128])
inner_data = np.array([0.066, 0.049, 0.030, 0.013, 0.00, -0.009, -0.015, -0.017])

# Define the new model with a logistic function
def logistic_decay_model(X, a, b, intercept):
    return  1/(1+np.exp(-(intercept+a*X))) - b #a - b*np.log2(X) #2**-a*X - b #(a*1*(1-X/K) - b*X) #(1 / (1 + np.exp(-a * X)) - b*np.log2(X)) 

# Define residuals for least squares fitting
def residuals(params, X, y):
    a, b, intercept = params
    return np.sum((logistic_decay_model(X, a, b, intercept) - y)**2)

# Constraint: steady state at X=16
def constraint(params):
    a, b, intercept = params
    return 1/(1+np.exp(-(intercept+a*16))) - b #a - b*np.log2(16) #2**(-a*16) - b #(a*1*(1-16/K) - b*16) #1 / (1 + np.exp(-a * 16)) - b*np.log2(16)

# Initial guess and bounds
initial_guess = [0.02, 0.08, -5]
cons = {'type': 'eq', 'fun': constraint}
bounds = [(-100, 100), (-100, 100), (-100, 100)]


# Fit model
result = minimize(residuals, initial_guess, args=(X_data, inner_data), constraints=cons, bounds=bounds)
a_fit_logistic, b_fit_logistic, intercept_fit_logistic = result.x

# Generate fitted curve
X_fit_range = np.linspace(min(X_data), max(X_data), 500)
y_fit_logistic = logistic_decay_model(X_fit_range, a_fit_logistic, b_fit_logistic, intercept_fit_logistic)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(X_data, inner_data, 'o', label='Given data')
plt.plot(X_fit_range, y_fit_logistic, '-', label=f'Fit: a={a_fit_logistic:.6f}, b={b_fit_logistic:.6f}, intercept={intercept_fit_logistic:.6f}')
plt.axhline(0, color='gray', linestyle='--')
plt.xscale('log', base=2)
plt.xlabel('X (log₂ scale)')
plt.ylabel('div-death rate')
plt.title('Fit with logistic division probability (sigma(intercept, a, X))) and constant death (b)\nConstrained: steady state at X=16')
plt.grid(True, which='both', linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# constrained variant to ensure the steady state at X=16 (where a=16b)

# Redefine the model with the constraint a = 16 * b => a - bX = b(16 - X)
def constrained_model(X, b):
    return b * (16 - X)

# Fit the constrained model
from scipy.optimize import curve_fit
b_constrained, _ = curve_fit(constrained_model, X_data, inner_data)
a_constrained = 16 * b_constrained[0]

# Generate smooth curve for plotting
X_fit_constrained = np.linspace(1, 130, 500)
inner_fit_constrained = constrained_model(X_fit_constrained, b_constrained[0])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(X_data, inner_data, 'o', label='Given data')
plt.plot(X_fit_constrained, inner_fit_constrained, '-', label=f'Constrained fit: a = {a_constrained:.5f}, b = {b_constrained[0]:.5f}')
plt.axhline(0, color='gray', linestyle='--')
plt.xlabel('X')
plt.ylabel('a - bX')
plt.title('Constrained Fit with a = 16 * b')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plot the constrained fit over a log2-scaled x-axis
plt.figure(figsize=(10, 6))
plt.plot(X_data, inner_data, 'o', label='Given data')
plt.plot(X_fit_constrained, inner_fit_constrained, '-', label=f'Constrained fit: a = {a_constrained:.5f}, b = {b_constrained[0]:.5f}')
plt.axhline(0, color='gray', linestyle='--')
plt.xscale('log', base=2)
plt.xlabel('X (log₂ scale)')
plt.ylabel('a - bX')
plt.title('Constrained Fit with a = 16 * b (log₂ X-axis)')
plt.grid(True, which='both', linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

a_constrained, b_constrained[0] #it seems the ODE will struggle to capture the figure S2H results properly, but still, this gives us an initial direction.

# %%
from osdr_validation.phase_portrait import plot_phase_portrait

plot_phase_portrait()
# Out:
# F cells expected SS: 16.0
# M cells expected SS: 16.0
# [array([0., 0.]), array([16.,  0.]), array([ 0., 16.]), array([16., 16.])]
# Unstable
# Unstable
# Unstable
# Stable

# %% [markdown]
# # 2. Simulation of cell distribution data biased by predefined model of division/death

# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.spatial import cKDTree

# %%
# parameters
cells=["F","M"] #cell type list

#n=100 #steps for stochastic proliferation

x_boundaries=(0,2500) #tissue size x boundaries in microns
y_boundaries=(0,2500) #tissue size y boundaries in microns

r=80 #neighbourhood radius in microns, same as in Somer et al.

#mF_rates=[0.066,0.049,0.030,0.013,0.00,-0.009,-0.015,-0.017] #division-death rate of mF based on #mF in neighbourhood
#M_rates=[0.066,0.049,0.030,0.013,0.00,-0.009,-0.015,-0.017] #same but with M for #M neibourhood

# %%
# 1. Sample a random initial number of cells for each type (integrated in the next block)
mF_num=round(np.random.uniform(1, 10000))
print(f"Number of mF cells chosen: {mF_num}.")
M_num=round(np.random.uniform(1, 10000))
print(f"Number of M cells chosen: {M_num}.")
# Out:
# Number of mF cells chosen: 8712.
# Number of M cells chosen: 5715.

# %%
# 2. Sample a random spatial position in the tissue for each cell.


def random_tissue(cells):
    cell_type=[]
    position_x=[]
    position_y=[]
    for cell in cells:
        cell_num=np.random.randint(4400, 4600)
        print(f"Number of {cell} cells chosen: {cell_num}.")
        for i in range(0, cell_num):
            cell_type.append(f"{cell}")
            position_x.append(np.random.uniform(x_boundaries[0],x_boundaries[1]))
            position_y.append(np.random.uniform(y_boundaries[0],y_boundaries[1]))
    tissue=pd.DataFrame(list(zip(cell_type,position_x,position_y)), columns=["Cell_Type","X","Y"])
    
    # Get all spatial coordinates as array for query
    coordinates = tissue[['X', 'Y']].values
    
    for cell in cells:
        # Build KD-Trees for each cell
        tree = cKDTree(tissue[tissue['Cell_Type'] == cell][['X', 'Y']].values)
        #Search neihbourhood contents of the current cell type for all cells
        neighbours = [len(tree.query_ball_point(coords, r)) - (1 if cat == cell else 0)
               for coords, cat in zip(coordinates, tissue['Cell_Type'])]
        column_name=f"#{cell}_neighbours"
        tissue[column_name] = neighbours
        tissue[column_name+"_log2"] = np.log2(neighbours)
        print(np.isneginf(tissue[column_name+"_log2"]).any())
     
    return tissue

tissue=random_tissue(cells)
print(tissue.head())
# Out:
# Number of F cells chosen: 4464.
# Number of M cells chosen: 4430.
# False
# False
#   Cell_Type            X            Y  #F_neighbours  #F_neighbours_log2  \
# 0         F  1625.744734  2405.929819             11            3.459432
# 1         F  2040.788188   776.646230             11            3.459432
# 2         F   645.968553  2162.578265             10            3.321928
# 3         F  1954.245922   849.235649             14            3.807355
# 4         F  2370.135861   663.581874             11            3.459432
#
#    #M_neighbours  #M_neighbours_log2
# 0             17            4.087463
# 1             16            4.000000
# 2              9            3.169925
# 3             14            3.807355
# 4             16            4.000000

# %%
#Superposed cel plots
#Plot generated tissue with bivariate KDE method
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=tissue,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    #cmap='rocket',
    hue="Cell_Type",
    thresh=0.05,  
    levels=10,
)
plt.title('Bivariate KDE of Neighbour Counts (superposed)')
plt.xlabel('Number of Neighbours (F)')
plt.ylabel('Number of Neighbours (M)')
plt.grid(True)
plt.tight_layout()
plt.show()


#Separate plots
# Isolate cell type dataframes
df_F = tissue[tissue['Cell_Type'] == 'F']
df_M = tissue[tissue['Cell_Type'] == 'M']

# 2) KDE plot for F cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_F,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    cmap='mako',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (F cells)")
plt.xlabel("Number of Neighbours (F)")
plt.ylabel("Number of Neighbours (M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 3) KDE plot for M cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_M,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    cmap='rocket',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (M cells)")
plt.xlabel("Number of Neighbours (F)")
plt.ylabel("Number of Neighbours (M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
####LOG2 PLOTS####
#Superposed cel plots
#Plot generated tissue with bivariate KDE method
log2_tissue=tissue[np.isfinite(tissue["#F_neighbours_log2"]) & np.isfinite(tissue["#M_neighbours_log2"])]
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=log2_tissue,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    #cmap='rocket',
    hue="Cell_Type",
    thresh=0.05,  
    levels=10,
)
plt.title('Bivariate KDE of Neighbour Counts (superposed)')
plt.gca().get_legend().set_bbox_to_anchor((1.05, 0.5))
plt.gca().get_legend().set_loc('center left')
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel('Neighbour cell density (log2 F)')
plt.ylabel('Neighbour cell density (log2 M)')
plt.grid(True)
plt.tight_layout()
plt.show()


#Separate plots
# Isolate cell type dataframes
df_F = log2_tissue[log2_tissue['Cell_Type'] == 'F']
df_M = log2_tissue[log2_tissue['Cell_Type'] == 'M']

# 2) KDE plot for F cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_F,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    cmap='mako',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (F cells)")
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel("Neighbour cell density (log2 F)")
plt.ylabel("Neighbour cell density (log2 M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 3) KDE plot for M cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_M,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    cmap='rocket',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (M cells)")
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel("Neighbour cell density (log2 F)")
plt.ylabel("Neighbour cell density (log2 M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Show cells of the generated tissue

plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=tissue,
    x='X',
    y='Y',
    hue='Cell_Type',
    palette='colorblind',   
    s=5,             
    edgecolor='black',
    alpha=0.7
)
plt.title("Randomised tissue with two cell types")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## STOCHASTIC SIM

# %% [markdown]
# ### NON-PARALLELISED VERSION

# %%
from tqdm import tqdm
#F parameters
F_a=48*10**-4
F_b=3*10**-4

#M parameters
M_a=48*10**-4
M_b=3*10**-4


# 3. stochastic biased proliferation over n steps

def tissue_proliferation(tissue, n=100, t=1): #time value, multiplies the rates
    div_counter=0
    death_counter=0
    stay_counter=0
    for step in tqdm(range(0,n)):
        next_tissue=tissue.copy()
        dead_ids=[]

        for cell_id in range(0,len(tissue)):
            #get current cell
            cell=tissue.iloc[cell_id]

            #get event probabilities
            p_div=F_a*t if cell.iloc[0]=="F" else M_a*t
            p_death=F_b*cell.iloc[3]*t if cell.iloc[0]=="F" else M_b*cell.iloc[5]*t
            p_stay= 1 - p_div - p_death

            if p_stay < 0:
                print("Error with probability space")
                print(p_div)
                print(p_death)
                print(p_stay)
                print(p_div+p_death+p_stay)
                break

            #sample random event uniformly
            r1=np.random.uniform(0,1) #sample event for current cell

            #act on sampled event
            if r1 <= p_div: #division
                rx=np.random.uniform(-r,r)
                ry=np.random.uniform(-r,r)

                #prevent out of bounds and excessive proliferation on the edges
                if cell.iloc[1]+rx < 0 :
                    rx=np.random.uniform(0,r)
                elif cell.iloc[1]+rx > 2500 :
                    rx=np.random.uniform(-r,0)
                if cell.iloc[2]+ry < 0:
                    ry=np.random.uniform(0,r)
                elif cell.iloc[2]+ry > 2500:
                    ry=np.random.uniform(-r,0)
                
                new_cell=[cell.iloc[0],cell.iloc[1]+rx,cell.iloc[2]+ry,2,1,2,1]

                next_tissue.loc[len(next_tissue)]=new_cell
                
                div_counter+=1
            elif r1 <=p_div+p_death: #death
                dead_ids.append(cell_id)
                death_counter+=1
            elif r1<=p_div+p_death+p_stay: #nothing happens
                stay_counter+=1
                pass
            else: #if triggered, I made a mistake in the handling/definition of the events
                print("Unexpected random number.")
                break
        
        #remove chosen dead cells
        next_tissue=next_tissue.drop(dead_ids)
        next_tissue=next_tissue.reset_index(drop=True)

        #recompute neighbours
        coordinates = next_tissue[['X', 'Y']].values
        for type in cells:
            # Build KD-Trees for each cell type
            tree = cKDTree(next_tissue[next_tissue['Cell_Type'] == type][['X', 'Y']].values)
            #Search neihbourhood contents of the current cell type for all cells
            neighbours = [len(tree.query_ball_point(coords, r)) - (1 if cat == type else 0)
                for coords, cat in zip(coordinates, next_tissue['Cell_Type'])]
            column_name=f"#{type}_neighbours"
            next_tissue[column_name] = neighbours
            with np.errstate(divide='ignore', invalid='ignore'): #only log2 of 0 are expected to be compute, leading to -inf values. The log2 plots ignore these so just silence runtime warnings.
                next_tissue[column_name+"_log2"] = np.log2(neighbours)

        tissue=next_tissue.copy()
    print(f"Divisions: {div_counter}\nDeaths: {death_counter}\nStay events: {stay_counter}")
    return tissue

# %%
#num_workers = 4
num_tasks = 10

# Use a random master seed to produce fresh seeds
master_seed = np.random.SeedSequence()  # new every run
child_seeds = master_seed.spawn(num_tasks)
######
rng = np.random.default_rng(1)
# Use rng for random numbers
x = rng.uniform(1, 10)
y=rng.uniform(1, 10)

# %%
print(x,y)
# Out:
# 5.606394622302311 9.554173266933418

# %% [markdown]
# ### PARALLELISED VERSION

# %%
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
#F parameters
F_a=48*10**-4
F_b=3*10**-4

#M parameters
M_a=48*10**-4
M_b=3*10**-4


# 3. stochastic biased proliferation over n steps

def cell_action(cell_id, t, seed):
            rng = np.random.default_rng(seed)
            global now_tissue
            #get current cell
            cell=now_tissue.iloc[cell_id]

            #get event probabilities
            p_div=F_a*t if cell.iloc[0]=="F" else M_a*t
            p_death=F_b*cell.iloc[3]*t if cell.iloc[0]=="F" else M_b*cell.iloc[5]*t
            p_stay= 1 - p_div - p_death

            if p_stay < 0:
                print("Error with probability space")
                print(p_div)
                print(p_death)
                print(p_stay)
                print(p_div+p_death+p_stay)
                return

            #sample random event uniformly
            r1=rng.uniform(0,1) #sample event for current cell

            #act on sampled event
            if r1 <= p_div: #division
                rx=rng.uniform(-r,r)
                ry=rng.uniform(-r,r)

                #prevent out of bounds and excessive proliferation on the edges
                if cell.iloc[1]+rx < 0 :
                    rx=rng.uniform(0,r)
                elif cell.iloc[1]+rx > 2500 :
                    rx=rng.uniform(-r,0)
                if cell.iloc[2]+ry < 0:
                    ry=rng.uniform(0,r)
                elif cell.iloc[2]+ry > 2500:
                    ry=rng.uniform(-r,0)
                
                new_cell=[cell.iloc[0],cell.iloc[1]+rx,cell.iloc[2]+ry,2,1,2,1]
                return new_cell

                #next_tissue.loc[len(next_tissue)]=new_cell
                
            elif r1 <=p_div+p_death: #death
                #dead_ids.append(cell_id)
                return cell_id
            elif r1<=p_div+p_death+p_stay: #nothing happens
                return None
            else: #if triggered, I made a mistake in the handling/definition of the events
                print("Unexpected random number.")
                return "Error"

def tissue_proliferation(tissue, n=100, t=1): #time value, multiplies the rates
    global now_tissue
    now_tissue=tissue.copy()
    div_counter=0
    death_counter=0
    stay_counter=0
    for step in tqdm(range(0,n)):
        ###prepare controlled random seeding for the parallelised tasks
        num_tasks = len(now_tissue.index)
        # Use a random master seed to produce fresh seeds
        master_seed = np.random.SeedSequence()  # new every run
        child_seeds = master_seed.spawn(num_tasks)
        
        ###safely set the next iteration of the dataframe for edits rather than the current one being looked into
        next_tissue=now_tissue.copy()
        #ids of dead cell row storage
        dead_ids=[]


        #argument list for starmap
        starguments=[(cell_id, t, seed) for cell_id, seed in zip(now_tissue.index, child_seeds)]

        #parallelise cell-specific event sampling and post-process results
        with Pool(processes=cpu_count()) as pool:
            results = pool.starmap(cell_action, starguments)
        for result in results:
            if type(result)==int:
                dead_ids.append(result)
                death_counter+=1
            elif type(result)==list:
                next_tissue.loc[len(next_tissue)]=result
                div_counter+=1
            elif type(result)==type(None):
                stay_counter+=1
            elif result=="Error":
                raise ValueError
            else:
                print("Unexpected starmap result while parsing.")
                print(type(result))
                
        #remove chosen dead cells
        next_tissue=next_tissue.drop(dead_ids)
        next_tissue=next_tissue.reset_index(drop=True)

        #recompute neighbours
        coordinates = next_tissue[['X', 'Y']].values
        for ctype in cells:
            # Build KD-Trees for each cell type
            tree = cKDTree(next_tissue[next_tissue['Cell_Type'] == ctype][['X', 'Y']].values)
            #Search neihbourhood contents of the current cell type for all cells
            neighbours = [len(tree.query_ball_point(coords, r)) - (1 if cat == ctype else 0)
                for coords, cat in zip(coordinates, next_tissue['Cell_Type'])]
            column_name=f"#{ctype}_neighbours"
            next_tissue[column_name] = neighbours
            with np.errstate(divide='ignore', invalid='ignore'): #only log2 of 0 are expected to be compute, leading to -inf values. The log2 plots ignore these so just silence runtime warnings.
                next_tissue[column_name+"_log2"] = np.log2(neighbours)

        now_tissue=next_tissue.copy()
    print(f"Divisions: {div_counter}\nDeaths: {death_counter}\nStay events: {stay_counter}")
    return now_tissue

# %%
#Run simulation
proliferated_tissue=tissue_proliferation(tissue, n=200, t=1)
print(proliferated_tissue.head())
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# 100%|██████████| 200/200 [01:41<00:00,  1.96it/s]
# Divisions: 8819
# Deaths: 8037
# Stay events: 1838897
#   Cell_Type            X            Y  #F_neighbours  #F_neighbours_log2  \
# 0         F   645.968553  2162.578265              8            3.000000
# 1         F  1954.245922   849.235649             17            4.087463
# 2         F  2370.135861   663.581874             17            4.087463
# 3         F  1814.954640  1706.395494             18            4.169925
# 4         F  1615.534851   364.350453             20            4.321928
#
#    #M_neighbours  #M_neighbours_log2
# 0             11            3.459432
# 1             17            4.087463
# 2             22            4.459432
# 3             13            3.700440
# 4             11            3.459432

# %%
len(proliferated_tissue)
# Out:
# 10316

# %% [markdown]
# ## PLOTS

# %%
#Superposed cel plots
#Plot generated tissue with bivariate KDE method
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=proliferated_tissue,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    #cmap='rocket',
    hue="Cell_Type",
    thresh=0.05,  
    levels=10,
)
plt.title('Bivariate KDE of Neighbour Counts (superposed)')
plt.xlabel('Number of Neighbours (F)')
plt.ylabel('Number of Neighbours (M)')
plt.grid(True)
plt.tight_layout()
plt.show()


#Separate plots
# Isolate cell type dataframes
df_F = proliferated_tissue[proliferated_tissue['Cell_Type'] == 'F']
df_M = proliferated_tissue[proliferated_tissue['Cell_Type'] == 'M']

# 2) KDE plot for F cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_F,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    cmap='mako',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (F cells)")
plt.xlabel("Number of Neighbours (F)")
plt.ylabel("Number of Neighbours (M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 3) KDE plot for M cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_M,
    x='#F_neighbours',
    y='#M_neighbours',
    fill=False,
    cmap='rocket',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (M cells)")
plt.xlabel("Number of Neighbours (F)")
plt.ylabel("Number of Neighbours (M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
####LOG2 PLOTS####
#Superposed cel plots
#Plot generated tissue with bivariate KDE method
log2_tissue=proliferated_tissue[np.isfinite(proliferated_tissue["#F_neighbours_log2"]) & np.isfinite(proliferated_tissue["#M_neighbours_log2"])]
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=log2_tissue,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    #cmap='rocket',
    hue="Cell_Type",
    thresh=0.05,  
    levels=10,
)
plt.title('Bivariate KDE of Neighbour Counts (superposed)')
plt.gca().get_legend().set_bbox_to_anchor((1.05, 0.5))
plt.gca().get_legend().set_loc('center left')
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel('Neighbour cell density (log2 F)')
plt.ylabel('Neighbour cell density (log2 M)')
plt.grid(True)
plt.tight_layout()
plt.show()


#Separate plots
# Isolate cell type dataframes
df_F = log2_tissue[log2_tissue['Cell_Type'] == 'F']
df_M = log2_tissue[log2_tissue['Cell_Type'] == 'M']

# 2) KDE plot for F cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_F,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    cmap='mako',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (F cells)")
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel("Neighbour cell density (log2 F)")
plt.ylabel("Neighbour cell density (log2 M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 3) KDE plot for M cells
plt.figure(figsize=(7, 6))
sns.kdeplot(
    data=df_M,
    x='#F_neighbours_log2',
    y='#M_neighbours_log2',
    fill=False,
    cmap='rocket',
    thresh=0.05,
    levels=10
)
plt.title("Bivariate KDE of Neighbor Counts (M cells)")
plt.xticks(np.arange(0, 6, 1))
plt.yticks(np.arange(0, 6, 1))
plt.xlabel("Neighbour cell density (log2 F)")
plt.ylabel("Neighbour cell density (log2 M)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Show cells of the generated tissue
plt.figure(figsize=(8, 8))
sns.scatterplot(
    data=proliferated_tissue,
    x='X',
    y='Y',
    hue='Cell_Type',
    palette='colorblind',   
    s=5,             
    edgecolor='black',
    alpha=0.7
)
plt.title("Randomised tissue with two cell types")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. 100-Tissue simulation dataset

# %%
#Tissue initiation function

#Note: tissue generation and proliferation are parallelised, so the cell row steps remain unparallelised*

# imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.spatial import cKDTree
from tqdm import tqdm
import time
from multiprocessing import Pool, cpu_count

# global variables
cells=["F","M"] #cell type list

#n=100 #steps for stochastic proliferation

x_boundaries=(0,2500) #tissue size x boundaries in microns
y_boundaries=(0,2500) #tissue size y boundaries in microns

r=80 #neighbourhood radius in microns, same as in Somer et al.

#F parameters
F_a=48*10**-4
F_b=3*10**-4

#M parameters
M_a=48*10**-4
M_b=3*10**-4

#functions
def random_tissue(seed, cells, tissue_id):
    rng = np.random.default_rng(seed)

    idcol=[]
    cell_type=[]
    position_x=[]
    position_y=[]
    
    for cell in cells:
        cell_num=int(rng.integers(250, 9750))
        #print(f"Number of {cell} cells chosen: {cell_num}.")
        for i in range(0, cell_num):
            idcol.append(tissue_id)
            cell_type.append(f"{cell}")
            position_x.append(rng.uniform(x_boundaries[0],x_boundaries[1]))
            position_y.append(rng.uniform(y_boundaries[0],y_boundaries[1]))
    tissue=pd.DataFrame(list(zip(idcol,cell_type,position_x,position_y)), columns=["Tissue_ID","Cell_Type","X","Y"])
    
    # Get all spatial coordinates as array for query
    coordinates = tissue[['X', 'Y']].values
    
    for cell in cells:
        # Build KD-Trees for each cell
        tree = cKDTree(tissue[tissue['Cell_Type'] == cell][['X', 'Y']].values)
        #Search neihbourhood contents of the current cell type for all cells
        neighbours = [len(tree.query_ball_point(coords, r)) - (1 if cat == cell else 0)
               for coords, cat in zip(coordinates, tissue['Cell_Type'])]
        column_name=f"#{cell}_neighbours"
        tissue[column_name] = neighbours
        with np.errstate(divide='ignore', invalid='ignore'):
            tissue[column_name+"_log2"] = np.log2(neighbours)
        #print(np.isneginf(tissue[column_name+"_log2"]).any())
     
    return tissue
def wrapper1(args):
    return random_tissue(*args)

# 3. stochastic biased proliferation over n steps

def tissue_proliferation(seed, tissue, n=100, t=None): 
    if t==None: #if t is not given, only record the final time step
        t=n
    
    rng = np.random.default_rng(seed)

    div_counter=0
    death_counter=0
    stay_counter=0

    t_tracker=0 #when it hits the set t, record data and reset tracker. record final time point no matter what

    proliferation_results=pd.DataFrame(columns=tissue.columns)
    proliferation_results['Time_Step'] = pd.Series(dtype='int')
    
    for step in range(0,n):
        t_tracker+=1

        next_tissue=tissue.copy()
        dead_ids=[]

        for cell_id in range(0,len(tissue)):
            #get current cell
            cell=tissue.iloc[cell_id]

            #get event probabilities
            p_div=F_a if cell.iloc[1]=="F" else M_a
            p_death=F_b*cell.iloc[4] if cell.iloc[1]=="F" else M_b*cell.iloc[6]
            p_stay= 1 - p_div - p_death

            if p_stay < 0:
                print("Error with probability space")
                print(p_div)
                print(p_death)
                print(p_stay)
                print(p_div+p_death+p_stay)
                break

            #sample random event uniformly
            r1=rng.uniform(0,1) #sample event for current cell

            #act on sampled event
            if r1 <= p_div: #division
                rx=rng.uniform(-r,r)
                ry=rng.uniform(-r,r)

                #prevent out of bounds and excessive proliferation on the edges
                if cell.iloc[2]+rx < 0 :
                    rx=rng.uniform(0,r)
                elif cell.iloc[2]+rx > 2500 :
                    rx=rng.uniform(-r,0)
                if cell.iloc[3]+ry < 0:
                    ry=rng.uniform(0,r)
                elif cell.iloc[3]+ry > 2500:
                    ry=rng.uniform(-r,0)
                
                new_cell=[cell.iloc[0],cell.iloc[1],cell.iloc[2]+rx,cell.iloc[3]+ry,2,1,2,1]

                next_tissue.loc[len(next_tissue)]=new_cell
                
                div_counter+=1
            elif r1 <=p_div+p_death: #death
                dead_ids.append(cell_id)
                death_counter+=1
            elif r1<=p_div+p_death+p_stay: #nothing happens
                stay_counter+=1
                pass
            else: #if triggered, I made a mistake in the handling/definition of the events
                print("Unexpected random number.")
                break
        
        #remove chosen dead cells
        next_tissue=next_tissue.drop(dead_ids)
        next_tissue=next_tissue.reset_index(drop=True)

        #recompute neighbours
        coordinates = next_tissue[['X', 'Y']].values
        for ctype in cells:
            # Build KD-Trees for each cell type
            tree = cKDTree(next_tissue[next_tissue['Cell_Type'] == ctype][['X', 'Y']].values)
            #Search neihbourhood contents of the current cell type for all cells
            neighbours = [len(tree.query_ball_point(coords, r)) - (1 if cat == ctype else 0)
                for coords, cat in zip(coordinates, next_tissue['Cell_Type'])]
            column_name=f"#{ctype}_neighbours"
            next_tissue[column_name] = neighbours
            with np.errstate(divide='ignore', invalid='ignore'): #only log2 of 0 are expected to be computed, leading to -inf values. The log2 plots ignore these so just silence runtime warnings.
                next_tissue[column_name+"_log2"] = np.log2(neighbours)

        tissue=next_tissue.copy()

        #record tissue at appropriate time steps
        if step == n-1:
            recorded_tissue=tissue.copy()
            recorded_tissue["Time_Step"]=step+1

            proliferation_results = pd.concat([proliferation_results, recorded_tissue], ignore_index=True)
        elif t_tracker==t:
            recorded_tissue=tissue.copy()
            recorded_tissue["Time_Step"]=step+1

            proliferation_results = pd.concat([proliferation_results, recorded_tissue], ignore_index=True)
            t_tracker=0

    #print(f"Divisions: {div_counter}\nDeaths: {death_counter}\nStay events: {stay_counter}")
    return proliferation_results

def wrapper2(args):
    return tissue_proliferation(*args)

def simulate_model(replicates=100, n=1000, t=100): #t is the time interval to record tissue states for the final dataset
        start_time = time.time()
        ###prepare controlled random seeding for the parallelised tasks
        # Use a random master seed to produce fresh seeds
        master_seed = np.random.SeedSequence()  # new every run
        child_seeds = master_seed.spawn(replicates)
        arguments=[(seed, cells, t_id) for seed, t_id in zip(child_seeds, range(0,100))]
        print("Beginning tissue initialisation...")
        #Initialise random tissues
        with Pool(processes=cpu_count()) as pool:
            results1 = list(tqdm(pool.imap(wrapper1,arguments), total=len(arguments)))
            #results1 = pool.starmap(random_tissue, starguments)
            
        end_time = time.time()
        duration = end_time - start_time
        print(f"Done... This took about {round(duration)} second(s).")
        tissues = pd.concat(results1, ignore_index=True)
        
        #Get a new set of seeds for proliferation
        start_time = time.time()
        master_seed = np.random.SeedSequence()  # new every run
        child_seeds = master_seed.spawn(replicates)
        arguments=[(seed, tissue, n, t) for seed, tissue in zip(child_seeds, results1)]
        print("Beginning tissue proliferation...")
        #Tissue proliferation
        with Pool(processes=cpu_count()) as pool:
            results2 = list(tqdm(pool.imap(wrapper2,arguments), total=len(arguments)))
            #results2 = pool.starmap(tissue_proliferation, starguments)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Done... This took about {round(duration)} second(s).")
        proliferated_tissues = pd.concat(results2, ignore_index=True)

        return tissues, proliferated_tissues

# %%
#test proliferation
prolid=tissue_proliferation(0,random_tissue(0, ["F","M"], 0),100,50)
# Out:
# /tmp/ipykernel_32342/974145832.py:173: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   proliferation_results = pd.concat([proliferation_results, recorded_tissue], ignore_index=True)

# %%
#test again with more recording events to compare time taken
prolid=tissue_proliferation(0,random_tissue(0, ["F","M"], 0),100,20)
# Out:
# /tmp/ipykernel_32342/974145832.py:173: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   proliferation_results = pd.concat([proliferation_results, recorded_tissue], ignore_index=True)

# %%
#display test
display(prolid)
print(prolid["Time_Step"].unique())
# Out:
#       Tissue_ID Cell_Type            X            Y #F_neighbours  \
# 0             0         F   674.466784   102.433810            22
# 1             0         F    41.319089  2033.175598            16
# 2             0         F  1823.741402  1359.062479            27
# 3             0         F  2337.681059  2039.633885            25
# 4             0         F     6.846250  2143.510691            10
# ...         ...       ...          ...          ...           ...
# 66294         0         M  1006.060134    45.351214            22
# 66295         0         M  2447.236616   177.290824            18
# 66296         0         F   164.420978  1773.333743            24
# 66297         0         M  1567.704084  1330.484302            17
# 66298         0         M   272.672841   432.921699            25
#
#        #F_neighbours_log2 #M_neighbours  #M_neighbours_log2  Time_Step
# 0                4.459432            16            4.000000         20
# 1                4.000000            14            3.807355         20
# 2                4.754888            16            4.000000         20
# 3                4.643856            18            4.169925         20
# 4                3.321928            12            3.584963         20
# ...                   ...           ...                 ...        ...
# 66294            4.459432            19            4.247928        100
# 66295            4.169925            22            4.459432        100
# 66296            4.584963            20            4.321928        100
# 66297            4.087463            21            4.392317        100
# 66298            4.643856            20            4.321928        100
#
# [66299 rows x 9 columns]
# [ 20  40  60  80 100]

# %%
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#### RUN AND SAVE
initial_df, post_df = simulate_model(replicates=100, n=1000, t=100)

# Save df1 to a CSV file
filepath=r'../../data/simulated_tissues2.csv'
#initial_df.to_csv(filepath, index=False)
symlink=r'../data/simulated_tissues2.csv'
#os.symlink(filepath, symlink)

# Save df2 to a CSV file
filepath_post=r'../../data/simulated_tissues_post2.csv'
#post_df.to_csv(filepath_post, index=False)
symlink_post=r'../data/simulated_tissues_post2.csv'
#os.symlink(filepath_post, symlink_post)
print("Results saved.")
# Out:
# Beginning tissue initialisation...
# 100%|██████████| 100/100 [00:02<00:00, 42.73it/s]
# Done... This took about 3 second(s).
# Beginning tissue proliferation...
# 100%|██████████| 100/100 [1:44:28<00:00, 62.69s/it]
# Done... This took about 6269 second(s).
# Results saved.

# %%
#Load from saved dfs, use symbolic links
# Load df1 from CSV
initial_df = pd.read_csv('../data/simulated_tissues.csv')

# Load df2 from CSV
post_df = pd.read_csv('../data/simulated_tissues_post.csv')

# %%
#load dataset with time data (one recording of tissues every 100 steps towards an endpoint of t=1000)
# Load t=0 df from CSV
initial_df = pd.read_csv('../data/simulated_tissues2.csv')

# Load t=... from CSV
post_df = pd.read_csv('../data/simulated_tissues_post2.csv')

# %%
print(post_df)
# Out:
#          Tissue_ID Cell_Type            X            Y  #F_neighbours  \
# 0                0         F  1397.202632   344.460028              0
# 1                0         F  1446.412644  1220.337777              2
# 2                0         F  1725.740985  1286.893035              1
# 3                0         F  1610.214275   846.272191              4
# 4                0         F   383.069894    19.102864              8
# ...            ...       ...          ...          ...            ...
# 9831520         99         F  1616.294539   894.147790             16
# 9831521         99         F  2210.508130   142.295888             11
# 9831522         99         F  1840.527943   230.225746             21
# 9831523         99         M  2203.411952   788.174766             13
# 9831524         99         F  1248.870366  2000.283209              8
#
#          #F_neighbours_log2  #M_neighbours  #M_neighbours_log2  Time_Step
# 0                      -inf             29            4.857981        100
# 1                  1.000000             23            4.523562        100
# 2                  0.000000             26            4.700440        100
# 3                  2.000000             17            4.087463        100
# 4                  3.000000             15            3.906891        100
# ...                     ...            ...                 ...        ...
# 9831520            4.000000             20            4.321928       1000
# 9831521            3.459432             20            4.321928       1000
# 9831522            4.392317             22            4.459432       1000
# 9831523            3.700440             15            3.906891       1000
# 9831524            3.000000             13            3.700440       1000
#
# [9831525 rows x 9 columns]

# %% [markdown]
# ## 3.5 - Plot tissue content

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_average_neighbourhoods(initial_df, post_df):

    # Calculate the count of rows for each category
    count_i_df = pd.crosstab(initial_df['Tissue_ID'], initial_df['Cell_Type'])
    count_p_df = pd.crosstab(post_df['Tissue_ID'], post_df['Cell_Type'])

    #log2 adjustment for dfs
    log2_i_df=initial_df[np.isfinite(initial_df["#F_neighbours_log2"]) & np.isfinite(initial_df["#M_neighbours_log2"])]
    log2_p_df=post_df[np.isfinite(post_df["#F_neighbours_log2"]) & np.isfinite(post_df["#M_neighbours_log2"])]
    # Calculate the average of neighbourhood counts
    average_i_df = log2_i_df.groupby('Tissue_ID')[['#F_neighbours_log2', '#M_neighbours_log2']].mean().reset_index()
    average_p_df = log2_p_df.groupby('Tissue_ID')[['#F_neighbours_log2', '#M_neighbours_log2']].mean().reset_index()
    melted_ai_df = average_i_df.melt(id_vars='Tissue_ID', var_name='variable', value_name='average')
    melted_ap_df = average_p_df.melt(id_vars='Tissue_ID', var_name='variable', value_name='average')

    # Plot count I
    
    count_i_df.plot(kind='bar', stacked=True, figsize=(20, 8), colormap='viridis')

    plt.xlabel('Tissue_ID')
    plt.ylabel('Number of Cells')
    plt.title('Cell type count per initiated tissue')
    #plt.xticks(rotation=90)
    plt.legend(title='Type')
    plt.tight_layout()
    plt.show()

    # Plot count P
    count_p_df.plot(kind='bar', stacked=True,figsize=(20, 8), colormap='viridis')

    plt.xlabel('Tissue_ID')
    plt.ylabel('Number of Cells')
    plt.title('Cell type count per proliferated tissue')
    #plt.xticks(rotation=90)
    plt.legend(title='Type')
    plt.tight_layout()
    plt.show()

    # Plot average I
    plt.figure(figsize=(20, 8))
    sns.barplot(data=melted_ai_df, x='Tissue_ID', y='average', hue='variable')
    plt.xticks(rotation=90)
    plt.xlabel('Tissue_ID')
    plt.ylabel('Average log2 neighbour density')
    plt.title('Average of F and M log2 neighbour densities per tissue')
    plt.tight_layout()
    plt.show()

    # Plot average P
    plt.figure(figsize=(20, 8))
    sns.barplot(data=melted_ap_df, x='Tissue_ID', y='average', hue='variable')
    plt.xticks(rotation=90)
    plt.xlabel('Tissue_ID')
    plt.ylabel('Average log2 neighbour density')
    plt.title('Average of F and M log2 neighbour densities per tissue')
    plt.tight_layout()
    plt.show()

#plot_average_neighbourhoods(initial_df, post_df)

# %%
def neighbourhoods_over_time(initial_df, post_df, tissue_id=0):
    #Select tissue from dataframe
    initial_tissue=initial_df.loc[initial_df["Tissue_ID"]==tissue_id].copy()
    post_tissue=post_df.loc[post_df["Tissue_ID"]==tissue_id].copy()

    #log2 adjustment for dfs
    log2_i_df=initial_tissue[np.isfinite(initial_tissue["#F_neighbours_log2"]) & np.isfinite(initial_tissue["#M_neighbours_log2"])]
    log2_p_df=post_tissue[np.isfinite(post_tissue["#F_neighbours_log2"]) & np.isfinite(post_tissue["#M_neighbours_log2"])]

    #x axis container
    time_steps=[0]

    # Containers for counts and neighbourhood averages
    counts_F=[]
    counts_M=[]
    neighmean_F=[]
    neighmean_M=[]
    
    #at t=0
    counts_F.append((initial_tissue["Cell_Type"]=="F").sum())
    counts_M.append((initial_tissue["Cell_Type"]=="M").sum())
    neighmean_F.append((log2_i_df["#F_neighbours_log2"]).mean())
    neighmean_M.append((log2_i_df["#M_neighbours_log2"]).mean())

    #at all time steps
    for step in post_tissue["Time_Step"].unique():
        df=post_tissue.loc[post_tissue["Time_Step"]==step]
        log2_df=log2_p_df.loc[log2_p_df["Time_Step"]==step]

        time_steps.append(step)
        
        counts_F.append((df["Cell_Type"]=="F").sum())
        counts_M.append((df["Cell_Type"]=="M").sum())
        
        neighmean_F.append((log2_df["#F_neighbours_log2"]).mean())
        neighmean_M.append((log2_df["#M_neighbours_log2"]).mean())


    
    #Plots
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

    # Overall cell count
    ax1.plot(time_steps, counts_F, color='orange', linestyle='-', label='F')
    ax1.plot(time_steps, counts_M, color='blue', linestyle='-', label='M')
    ax1.set_title('Cell counts')
    ax1.set_xlabel('Time steps')
    ax1.set_ylabel('Count')
    ax1.legend()

    # Neighbourhood plot
    ax2.plot(time_steps, neighmean_F, color='green', linestyle='-', label='F neighbourhood content')
    ax2.plot(time_steps, neighmean_M, color='purple', linestyle='-', label='M neighbourhood content')
    ax2.set_title('Neighbourhood densities')
    ax2.set_xlabel('Time steps')
    ax2.set_ylabel('Average neighbourhood density (log2)')
    ax2.legend()
 

    # Global title
    fig.suptitle(f'Cell counts and average neighbourhood densities in tissue {tissue_id}', fontsize=16)

    # Display plots
    plt.tight_layout()
    plt.show()
neighbourhoods_over_time(initial_df, post_df, 99)

# %% [markdown]
# ## 4. Post-proliferation cell sampling

# %%
import numpy as np
import pandas as pd

def cell_sampler(post_df, t=None, seed=0):

    #isolate desired time step data
    if t!=None and type(t)==int:
        post_df=post_df.loc[post_df["Time_Step"]==t].copy()
        print(f"\nCell Sampler : Now processing data at t={t}.\n")
    
    #use a seeded number generator
    rng = np.random.default_rng(seed)

    sampled_cells=[]

    #sample with replacement 50k cells evenly across tissues (5k cells/tissue) from the post-proliferation dataset of 100 tissues
    for tissue_id in range(0, 100):
        cell_ids=post_df.index[post_df["Tissue_ID"]==tissue_id].tolist()
        startid=min(cell_ids)
        stopid=max(cell_ids)
        for i in range(0,500):
            sampled_cells.append(int(rng.integers(startid,stopid)))

    main_sample=post_df.loc[sampled_cells].copy() #switch from iloc to loc

    print(f"Done sampling cell data. {len(main_sample)} cells sampled.")

    #make smaller samples from the patchwork cell data (1k cells, 5k, 10k, 25k)
    idrange=range(0,len(main_sample))

    k1_ids=rng.choice(idrange, size=1000, replace=False)
    k5_ids=rng.choice(idrange, size=5000, replace=False)
    k10_ids=rng.choice(idrange, size=10000, replace=False)
    k25_ids=rng.choice(idrange, size=25000, replace=False)
    
    print("Done choosing sampled cells for child dataframes.")
    k1_df=main_sample.iloc[k1_ids].copy()
    print(f"Child 1: {len(k1_df)} cells.")
    #print(k1_df.index.duplicated().sum()) #used to check duplicates
    k5_df=main_sample.iloc[k5_ids].copy()
    print(f"Child 2: {len(k5_df)} cells.")
    k10_df=main_sample.iloc[k10_ids].copy()
    print(f"Child 3: {len(k10_df)} cells.")
    k25_df=main_sample.iloc[k25_ids].copy()
    print(f"Child 4: {len(k25_df)} cells.")
    
    sample_dfs=(main_sample, k1_df, k5_df, k10_df, k25_df)
    print("Done generating child dataframes.")
    return sample_dfs

#main_sample, k1_df, k5_df, k10_df, k25_df  = cell_sampler(post_df)

# %%
print(k1_df)
# Out:
#         Tissue_ID Cell_Type            X            Y  #F_neighbours  \
# 225294         22         M   214.148139   230.572922             16
# 534790         52         F  2420.333159  1139.373397             14
# 411950         40         F  1584.307652  2461.707160             12
# 314845         30         M  2290.075725  1317.149821             11
# 981477         96         M  1715.585859   795.909375             11
# ...           ...       ...          ...          ...            ...
# 589912         57         F  1347.203912   225.984119             14
# 566929         55         F    98.982048   342.153613             19
# 191801         18         M  1505.576045  1606.127320             16
# 249022         24         M  2045.025396   383.315625             17
# 201090         19         F    36.906274  1450.636263             13
#
#         #F_neighbours_log2  #M_neighbours  #M_neighbours_log2
# 225294            4.000000             23            4.523562
# 534790            3.807355             23            4.523562
# 411950            3.584963              9            3.169925
# 314845            3.459432             12            3.584963
# 981477            3.459432              9            3.169925
# ...                    ...            ...                 ...
# 589912            3.807355             21            4.392317
# 566929            4.247928             16            4.000000
# 191801            4.000000             18            4.169925
# 249022            4.087463             11            3.459432
# 201090            3.700440             13            3.700440
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## 5. Model inference with multivariate logistic regression

# %%
from sklearn.linear_model import LogisticRegression

#F parameters
F_a=48*10**-4
F_b=3*10**-4

#M parameters
M_a=48*10**-4
M_b=3*10**-4

def tissue_regression(post_df, t=None, seed=0, broadcast=False): #given sampled tissue data, will select from dataset at timepoint t
    rng = np.random.default_rng(seed)

    main_sample, k1_df, k5_df, k10_df, k25_df  = cell_sampler(post_df, t, seed)
    k_dfs=[k1_df, k5_df, k10_df, k25_df]

    #X_dict={}
    if broadcast==True: #if the broadcast argument is given as True, make the y_dict a global variable. This is implemented this way to limit time spent on refactoring the function and others where y_dict would have to be passed around in return/args.
        global y_dict
    y_dict={}
    for i, df in enumerate(k_dfs):
        y_dict[i]=[] #storing sample-specific labels
        for cell_id in range(0,len(df)):
            #current cell
            cell=df.iloc[cell_id]

            #event probabilities
            p_div=F_a if cell.iloc[1]=="F" else M_a
            p_death=F_b*cell.iloc[4] if cell.iloc[1]=="F" else M_b*cell.iloc[6]
            p_stay= 1 - p_div - p_death

            if p_stay < 0:
                print("Error with probability space")
                print(p_div)
                print(p_death)
                print(p_stay)
                print(p_div+p_death+p_stay)
                return
            #sample random event uniformly
            r1=rng.uniform(0,1) #sample event for current cell

            #register sampled event as a binary observation for division
            if r1 <= p_div: #division
                y_dict[i].append(1) #score 1 for binary division observation
            elif r1 <=p_div+p_death: #death
                y_dict[i].append(0) #not division
            elif r1<=p_div+p_death+p_stay: #nothing happens
                y_dict[i].append(0) #still no division
            else: #if triggered, I made a mistake in the handling/definition of the events
                print("Unexpected random number.")
                return
    
    print(f"Completed generation of label y dictionary, with {len(y_dict)} lists stored.")
    print(f"k1 div count: {y_dict[0].count(1)}, p- all ~= {y_dict[0].count(1)/len(y_dict[0])}")
    print(f"k5 div count: {y_dict[1].count(1)}, p- all ~= {y_dict[1].count(1)/len(y_dict[1])}")
    print(f"k10 div count: {y_dict[2].count(1)}, p- all ~= {y_dict[2].count(1)/len(y_dict[2])}")
    print(f"k25 div count: {y_dict[3].count(1)}, p- all ~= {y_dict[3].count(1)/len(y_dict[3])}")
    
    #update dfs with y
    for i, df in enumerate(k_dfs):
        df["Division_Observation"]=y_dict[i]

    #Set parameter dictionaries, one entry per k_df
    pplus_f={}
    pplus_m={}
    pminus_f={}
    pminus_m={}
    print("\n#####INFERENCE#####")

    for i, df in enumerate(k_dfs):
        #fit multivaraite logistic regression model for each cell type given the expected features of each model
        X_f=df[["#F_neighbours"]].loc[df["Cell_Type"]=="F"].copy() #in a broader scenario, all cell types would be used as features, here focus on expectations from known model
        y_f=df["Division_Observation"].loc[df["Cell_Type"]=="F"].copy()
        X_m=df[["#M_neighbours"]].loc[df["Cell_Type"]=="M"].copy()
        y_m=df["Division_Observation"].loc[df["Cell_Type"]=="M"].copy()
    
        model_f=LogisticRegression(random_state=seed).fit(X_f, y_f)
        model_m=LogisticRegression(random_state=seed).fit(X_m, y_m)

        # Get model parameters
        coefficients_f = model_f.coef_
        intercept_f = model_f.intercept_
        coefficients_m = model_m.coef_
        intercept_m = model_m.intercept_

        #Print out some summary values to visualise coefficients and the parameter values inferred.
        print(f"Coefficients of df {i} (F/M):", coefficients_f[0], "/", coefficients_m[0])
        print(f"Intercept of df {i} (F/M):", intercept_f, "/", intercept_m)

        X_testf={"#F_neighbours":[16]}
        X_testf=pd.DataFrame(X_testf)
        z_f=intercept_f + 16*coefficients_f[0][0] # + 16*coefficients_f[0][1]
        p_div_f=1/ (1 + np.exp(-z_f))
        print(f"p+ at known steady state for F, df{i}: {model_f.predict_proba((X_testf))[0][1]}\n...manual computation with logistic function gives: {p_div_f}\n")

        X_testm={"#M_neighbours":[16]}
        X_testm=pd.DataFrame(X_testm)
        z_m=intercept_m + 16*coefficients_m[0][0] # + 16*coefficients_m[0][1]
        p_div_m=1/ (1 + np.exp(-z_m))
        print(f"p+ at known steady state for M, df{i}: {model_m.predict_proba((X_testm))[0][1]}\n...manual computation with logistic function gives: {p_div_m}\n\n")

        #Store parameters
        pplus_f[i]=[intercept_f[0], coefficients_f[0][0]] #for coefficients, i am directly removing the only value from the array, but the aproach would be a bit different if I have more coefs to deal with
        pplus_m[i]=[intercept_m[0], coefficients_m[0][0]]
        pminus_f[i]=y_f.mean()
        pminus_m[i]=y_m.mean()

    print("\n\nReturning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k")
    return pplus_f, pplus_m, pminus_f, pminus_m

# %%
pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df)
# Out:
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 5, p- all ~= 0.005
# k5 div count: 29, p- all ~= 0.0058
# k10 div count: 41, p- all ~= 0.0041
# k25 div count: 123, p- all ~= 0.00492
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.11207631] / [0.14837961]
# Intercept of df 0 (F/M): [-3.46726691] / [-8.06289666]
# p+ at known steady state for F, df0: 0.005165945023058515
# ...manual computation with logistic function gives: [0.00516595]
#
# p+ at known steady state for M, df0: 0.003372163459101643
# ...manual computation with logistic function gives: [0.00337216]
#
#
# Coefficients of df 1 (F/M): [0.04572063] / [0.01406073]
# Intercept of df 1 (F/M): [-5.92804235] / [-5.3296658]
# p+ at known steady state for F, df1: 0.005505361681851227
# ...manual computation with logistic function gives: [0.00550536]
#
# p+ at known steady state for M, df1: 0.006031594129514189
# ...manual computation with logistic function gives: [0.00603159]
#
#
# Coefficients of df 2 (F/M): [-0.02231846] / [-0.06786053]
# Intercept of df 2 (F/M): [-5.1705195] / [-4.43771852]
# p+ at known steady state for F, df2: 0.0039597182733335495
# ...manual computation with logistic function gives: [0.00395972]
#
# p+ at known steady state for M, df2: 0.003976032171776946
# ...manual computation with logistic function gives: [0.00397603]
#
#
# Coefficients of df 3 (F/M): [-0.05800586] / [0.03788152]
# Intercept of df 3 (F/M): [-4.43835874] / [-5.9029649]
# p+ at known steady state for F, df3: 0.004648957726519849
# ...manual computation with logistic function gives: [0.00464896]
#
# p+ at known steady state for M, df3: 0.00498234137166152
# ...manual computation with logistic function gives: [0.00498234]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k

# %%
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}
params
# Out:
# {'pplus_f': {0: [np.float64(-3.467266908111828),
#    np.float64(-0.11207631147965431)],
#   1: [np.float64(-5.9280423513545975), np.float64(0.04572063206465663)],
#   2: [np.float64(-5.170519498574373), np.float64(-0.022318457628441684)],
#   3: [np.float64(-4.438358739805286), np.float64(-0.05800585573726159)]},
#  'pplus_m': {0: [np.float64(-8.06289666345906),
#    np.float64(0.14837961005463707)],
#   1: [np.float64(-5.329665802887026), np.float64(0.014060732737178686)],
#   2: [np.float64(-4.43771852488877), np.float64(-0.06786052601475415)],
#   3: [np.float64(-5.902964896438527), np.float64(0.03788152172329477)]},
#  'pminus_f': {0: np.float64(0.005813953488372093),
#   1: np.float64(0.005573248407643312),
#   2: np.float64(0.0039904229848363925),
#   3: np.float64(0.004834031582339671)},
#  'pminus_m': {0: np.float64(0.004132231404958678),
#   1: np.float64(0.006028938906752411),
#   2: np.float64(0.004210104250200481),
#   3: np.float64(0.005004766444232603)}}

# %%
#code to switch param values, useless but kept in case loop format is useful elsewhere
def neg_params(params):
    new_params=params.copy()
    for set in new_params:
        for t_id in new_params[set]:
            if type(new_params[set][t_id])==list:
                for i, param in enumerate(new_params[set][t_id]):
                    if param >0:
                        new_params[set][t_id][i]=-1*new_params[set][t_id][i]
            else:
                pass
                #if new_params[set][t_id] >0:
                #    new_params[set][t_id] = -1*new_params[set][t_id]
                
    return new_params

# %% [markdown]
# ## 6. Phase portraits of inferred models

# %%
#####################################
# PHASE PORTRAIT of INFERRED MODELS #
#####################################
from scipy.optimize import fsolve
#from scipy.integrate import odeint
import autograd.numpy as np
from autograd import jacobian
import matplotlib.pyplot as plt
#######################################
##### OSDR model parameters #####
#######################################

# After the description of the neighbourhood dynamics ODE in Methods, we have
# dX/dt = X(p^+(X) - p^-(X)), with constant division rate parameter p^+(X) = sigma(z), with sigma as the logistic function. z is w0 + w1*X1 + w2*X2..., where w is a model parameter and Xi the number of a cell type i within the neighbourhood radius of a given cell
# ...and death rate parameter p^-, the mean of division observations in the data used to train the inferred model (dividing cells/total cells).

# Steady state: 


pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df)
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

# Define the system of ODEs
def ODE_system(state, params, t_id):
    F, M = state

    #only look at model from 1k sample first
    z_f = params["pplus_f"][t_id][0] + F*params["pplus_f"][t_id][1]
    pp_f = 1/ (1 + np.exp(-z_f))
    pm_f = params["pminus_f"][t_id]

    z_m = params["pplus_m"][t_id][0] + M*params["pplus_m"][t_id][1]
    pp_m = 1/ (1 + np.exp(-z_m))
    pm_m = params["pminus_m"][t_id]

    dF_dt = F * (pp_f - pm_f)
    dM_dt = M * (pp_m - pm_m)
    return [dF_dt, dM_dt]

def ODE_system_np(state, params, t_id):
    F, M = state

    #only look at model from 1k sample first
    z_f = params["pplus_f"][t_id][0] + F*params["pplus_f"][t_id][1]
    pp_f = 1/ (1 + np.exp(-z_f))
    pm_f = params["pminus_f"][0]

    z_m = params["pplus_m"][t_id][0] + M*params["pplus_m"][t_id][1]
    pp_m = 1/ (1 + np.exp(-z_m))
    pm_m = params["pminus_m"][t_id]

    dF_dt = F * (pp_f - pm_f)
    dM_dt = M * (pp_m - pm_m)

    return np.array([dF_dt, dM_dt])


# Generate rates for streamlines adapted to the log2 scale
def streamlines(exp_F, exp_M, params, t_id):
    F = 2**exp_F
    M = 2**exp_M
    dF_dt, dM_dt = ODE_system([F, M], params, t_id)
    return dF_dt, dM_dt




# Plot the phase portrait
def plot_inferred_portrait(params, t_id=0):
    # Parameters for meshgrid
    exp_F_mesh = np.linspace(0, 8, 30)
    exp_M_mesh = np.linspace(0, 8, 30)
    exp_F, exp_M = np.meshgrid(exp_F_mesh, exp_M_mesh)

    # Calculate the growth rates for the streamlines
    F_rate, M_rate = streamlines(exp_F, exp_M, params, t_id)
    F_rate_scaled = F_rate / (2**exp_F)
    M_rate_scaled = M_rate / (2**exp_M)
    
    plt.figure()

    # Streamplot
    plt.streamplot(exp_F, exp_M, F_rate_scaled, M_rate_scaled,
                   color="black")

    # Nullclines
    #F_range, M_range, F_nullcline, M_nullcline = nullclines()
    #plt.plot(np.log2(F_nullcline), np.log2(M_range), 'b-', label='F nullcline')
    #plt.plot(np.log2(F_range), np.log2(M_nullcline), 'r-', label='M nullcline')
    

    # Fixed points
    #fixed_points = find_fixed_points()
    #print(fixed_points)
    # with stability analysis
    

    # Labels and legend
    plt.xlabel('log2(F)')
    plt.ylabel('log2(M)')
    plt.xlim(0, 8)
    plt.ylim(0, 8)
    plt.legend()
    plt.title('Phase Portrait')
    plt.grid(True)
    plt.show()
# Out:
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 5, p- all ~= 0.005
# k5 div count: 29, p- all ~= 0.0058
# k10 div count: 41, p- all ~= 0.0041
# k25 div count: 123, p- all ~= 0.00492
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.10064694] / [0.14064801]
# Intercept of df 0 (F/M): [-7.89887436] / [-7.2313874]
# p+ at known steady state for F, df0: 0.001854056810906312
# ...manual computation with logistic function gives: [0.00185406]
#
# p+ at known steady state for M, df0: 0.006820225189167045
# ...manual computation with logistic function gives: [0.00682023]
#
#
# Coefficients of df 1 (F/M): [0.04021114] / [0.04670419]
# Intercept of df 1 (F/M): [-5.8531956] / [-5.81829998]
# p+ at known steady state for F, df1: 0.005432992999965366
# ...manual computation with logistic function gives: [0.00543299]
#
# p+ at known steady state for M, df1: 0.006236792855112071
# ...manual computation with logistic function gives: [0.00623679]
#
#
# Coefficients of df 2 (F/M): [0.08657616] / [0.0438071]
# Intercept of df 2 (F/M): [-6.84231656] / [-6.30190682]
# p+ at known steady state for F, df2: 0.004247796859347602
# ...manual computation with logistic function gives: [0.0042478]
#
# p+ at known steady state for M, df2: 0.0036805956524355345
# ...manual computation with logistic function gives: [0.0036806]
#
#
# Coefficients of df 3 (F/M): [0.01686034] / [0.01914515]
# Intercept of df 3 (F/M): [-5.57514703] / [-5.61276015]
# p+ at known steady state for F, df3: 0.004940276056177799
# ...manual computation with logistic function gives: [0.00494028]
#
# p+ at known steady state for M, df3: 0.00493508688597532
# ...manual computation with logistic function gives: [0.00493509]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k

# %%
#WIP version

#####################################
# PHASE PORTRAIT of INFERRED MODELS #
#####################################
from scipy.optimize import fsolve
#from scipy.integrate import odeint
import autograd.numpy as np
from autograd import jacobian
import matplotlib.pyplot as plt
#######################################
##### OSDR model parameters #####
#######################################

# After the description of the neighbourhood dynamics ODE in Methods, we have
# dX/dt = X(p^+(X) - p^-(X)), with constant division rate parameter p^+(X) = sigma(z), with sigma as the logistic function. z is w0 + w1*X1 + w2*X2..., where w is a model parameter and Xi the number of a cell type i within the neighbourhood radius of a given cell
# ...and death rate parameter p^-, the mean of division observations in the data used to train the inferred model (dividing cells/total cells).



# Define the system of ODEs
def ODE_system(state, params, t_id):
    F, M = state

    #only look at model from 1k sample first
    z_f = params["pplus_f"][t_id][0] + F*params["pplus_f"][t_id][1]
    pp_f = 1/ (1 + np.exp(-z_f))
    pm_f = params["pminus_f"][t_id]

    z_m = params["pplus_m"][t_id][0] + M*params["pplus_m"][t_id][1]
    pp_m = 1/ (1 + np.exp(-z_m))
    pm_m = params["pminus_m"][t_id]

    dF_dt = F * (pp_f - pm_f)
    dM_dt = M * (pp_m - pm_m)
    return [dF_dt, dM_dt]

def ODE_system_np(args):
    state, params, t_id = args
    F, M = state

    #only look at model from 1k sample first
    z_f = params["pplus_f"][t_id][0] + F*params["pplus_f"][t_id][1]
    pp_f = 1/ (1 + np.exp(-z_f))
    pm_f = params["pminus_f"][0]

    z_m = params["pplus_m"][t_id][0] + M*params["pplus_m"][t_id][1]
    pp_m = 1/ (1 + np.exp(-z_m))
    pm_m = params["pminus_m"][t_id]

    dF_dt = F * (pp_f - pm_f)
    dM_dt = M * (pp_m - pm_m)

    return np.array([dF_dt, dM_dt])


# Generate rates for streamlines adapted to the log2 scale
def streamlines(exp_F, exp_M, params, t_id):
    F = 2**exp_F
    M = 2**exp_M
    dF_dt, dM_dt = ODE_system([F, M], params, t_id)
    return dF_dt, dM_dt

# Define a function to find fixed points for the system from a matrix of points
def find_fixed_points(system, x_range, y_range, num_points, params, t_id): #ranges as tuples with start and end
    # Create a grid of points to test the system
    x_values = np.linspace(x_range[0], x_range[1], num_points)
    y_values = np.linspace(y_range[0], y_range[1], num_points)

    fixed_points = []

    for x in x_values:
        for y in y_values:
            # Use fsolve to find a fixed point
            point = fsolve(system, (x, y), args=(params, t_id))
            # Consider a point a fixed point if the vector field is close to zero
            if np.allclose(system(point, params, t_id), (0, 0), atol=1e-3):
                fixed_points.append(tuple(point))
    
    # Remove duplicates by converting to a set
    unique_fixed_points = list(set(fixed_points))
    return unique_fixed_points

# Calculate stability using the Jacobian
def is_stable(fp, params, t_id):
    jac = jacobian(ODE_system_np)
    J = jac((fp, params, t_id))
    eigenvalues = np.linalg.eigvals(J)
    return all(e.real < 0 for e in eigenvalues)

def is_unstable(fp, params, t_id):
    jac = jacobian(ODE_system_np)
    J = jac((fp, params, t_id))
    eigenvalues = np.linalg.eigvals(J)
    return any(e.real > 0 for e in eigenvalues)

# Plot the phase portrait
def plot_inferred_portrait(params, t_id=0):
    # Parameters for meshgrid
    exp_F_mesh = np.linspace(0, 8, 30)
    exp_M_mesh = np.linspace(0, 8, 30)
    exp_F, exp_M = np.meshgrid(exp_F_mesh, exp_M_mesh)

    # Calculate the growth rates for the streamlines
    F_rate, M_rate = streamlines(exp_F, exp_M, params, t_id)
    F_rate_scaled = F_rate / (2**exp_F)
    M_rate_scaled = M_rate / (2**exp_M)
    
    plt.figure()

    # Streamplot
    plt.streamplot(exp_F, exp_M, F_rate_scaled, M_rate_scaled,
                   color="black")

    # Nullclines
    #F_range, M_range, F_nullcline, M_nullcline = nullclines()
    #plt.plot(np.log2(F_nullcline), np.log2(M_range), 'b-', label='F nullcline')
    #plt.plot(np.log2(F_range), np.log2(M_nullcline), 'r-', label='M nullcline')
    

    # Fixed points
    xrange=(0, 30)
    yrange=(0, 30)

    fixed_points = find_fixed_points(ODE_system, xrange, yrange, 200, params, t_id)
    print(fixed_points)
    # with stability analysis
    label_added = {'Stable': False, 'Unstable': False, 'Semi-stable': False} #point label tracker to avoid redundancy
    for fp in fixed_points:
        x=(np.log2(fp[0])) if fp[0]!=0 else fp[0]
        y=(np.log2(fp[1])) if fp[1]!=0 else fp[1]
        stability=''
        if is_stable(fp, params, t_id):
            stability = 'Stable'
        elif is_unstable(fp, params, t_id):
            stability = 'Unstable'
        else:
            stability = 'Semi-stable'
        print(stability)
        fcolor = 'black' if stability == 'Stable' or stability == 'Semi-stable' else 'white'
        ecolor = 'black' if stability == 'Stable' or stability =='Unstable' else 'red'
        if label_added[stability]==False:
            plt.scatter(x, y, s=100, edgecolors=ecolor, facecolors=fcolor, label=f'{stability} Fixed Point', zorder=2)
            label_added[stability]=True
        else:
            plt.scatter(x, y, s=100, edgecolors=ecolor, facecolors=fcolor, zorder=2)
    

    # Labels and legend
    plt.xlabel('log2(F)')
    plt.ylabel('log2(M)')
    plt.xlim(0, 8)
    plt.ylim(0, 8)
    plt.legend()
    plt.title('Phase Portrait')
    plt.grid(True)
    plt.show()

# %%
#PLOT FOR one time point (remove t argument if first dataset, which doesn't feature time)
#from osdr_validation.inferred_portraits import plot_inferred_portrait
#alt_params=neg_params(params)


pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, t=1000, seed=1)
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

for i in range(0,4):
    plot_inferred_portrait(params, t_id=i)

# %%
#PLOT FOR TIME: intervals of 100 until maximum of 1000

for t in post_df["Time_Step"].unique():
    print(f"#####\n Now processing data at t={int(t)}.")

    pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, int(t), seed=1)
    params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

    for i in range(0,4):
        plot_inferred_portrait(params, t_id=i)
    print("#####")

# %%
#PLOT Multiple times (different seeds) for the same timestep in the same dataset
srange=list(range(0,9))
srange.append(10)
for s in srange:
    print(f"#####\nNow processing data at seed={int(s)}.")

    pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, 1000, seed=s)
    params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

    for i in range(0,4):
        plot_inferred_portrait(params, t_id=i)
    print("#####")

# %%
pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, t=1000, seed=1)
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}
print(pplus_f)
# Out:
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 3, p- all ~= 0.003
# k5 div count: 21, p- all ~= 0.0042
# k10 div count: 48, p- all ~= 0.0048
# k25 div count: 120, p- all ~= 0.0048
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.09611913] / [0.10395975]
# Intercept of df 0 (F/M): [-4.08591574] / [-7.95327919]
# p+ at known steady state for F, df0: 0.0035978238052385906
# ...manual computation with logistic function gives: [0.00359782]
#
# p+ at known steady state for M, df0: 0.0018514680200677266
# ...manual computation with logistic function gives: [0.00185147]
#
#
# Coefficients of df 1 (F/M): [0.04316078] / [0.05987906]
# Intercept of df 1 (F/M): [-6.43139119] / [-6.24515439]
# p+ at known steady state for F, df1: 0.00320185273695394
# ...manual computation with logistic function gives: [0.00320185]
#
# p+ at known steady state for M, df1: 0.005031016831264527
# ...manual computation with logistic function gives: [0.00503102]
#
#
# Coefficients of df 2 (F/M): [-0.1160918] / [-0.03288749]
# Intercept of df 2 (F/M): [-3.65883743] / [-4.77276302]
# p+ at known steady state for F, df2: 0.004004570749172801
# ...manual computation with logistic function gives: [0.00400457]
#
# p+ at known steady state for M, df2: 0.004971930231885452
# ...manual computation with logistic function gives: [0.00497193]
#
#
# Coefficients of df 3 (F/M): [-0.01001659] / [-0.00868961]
# Intercept of df 3 (F/M): [-5.28121736] / [-5.10058015]
# p+ at known steady state for F, df3: 0.004314358960055766
# ...manual computation with logistic function gives: [0.00431436]
#
# p+ at known steady state for M, df3: 0.005274337138326207
# ...manual computation with logistic function gives: [0.00527434]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# {0: [np.float64(-4.085915742126928), np.float64(-0.09611912882386016)], 1: [np.float64(-6.4313911887936195), np.float64(0.0431607826253915)], 2: [np.float64(-3.6588374270823723), np.float64(-0.11609180283395074)], 3: [np.float64(-5.281217363993902), np.float64(-0.010016591853010074)]}

# %%
#count models that have correct parameter signs (supports monovariate models for now)
def parameter_checker(srange):
    total=0
    gc_dict={0:0,1:0,2:0,3:0}

    for s in srange:
        print(f"Checking seed {s}")
        total+=1
        pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, 1000, seed=s)
        for sample in range(0,4):
            if pplus_f[sample][1]<0 and pplus_m[sample][1]<0:
                gc_dict[sample]+=1
    
    freq_good=[round(gc_dict[i]/total,2) for i in gc_dict.keys()]
    print("Checker completed, returning total and frequency of properly signed models per sample size")
    return total, freq_good

# %%
#Same thing, but just counting models where we get 2
srange=list(range(0,9))
srange.append(10)
srange=srange+list(range(13,19))
srange.append(21)
srange.append(24)
srange=srange+list(range(27, 29))
parameter_checker(srange)
# Out:
# Checking seed 0
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 5, p- all ~= 0.005
# k5 div count: 29, p- all ~= 0.0058
# k10 div count: 41, p- all ~= 0.0041
# k25 div count: 123, p- all ~= 0.00492
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.02605937] / [-0.02466262]
# Intercept of df 0 (F/M): [-6.6138762] / [-4.44162261]
# p+ at known steady state for F, df0: 0.002031542417530718
# ...manual computation with logistic function gives: [0.00203154]
#
# p+ at known steady state for M, df0: 0.007874463730132737
# ...manual computation with logistic function gives: [0.00787446]
#
#
# Coefficients of df 1 (F/M): [0.01211809] / [-0.0349577]
# Intercept of df 1 (F/M): [-5.2403815] / [-4.70987903]
# p+ at known steady state for F, df1: 0.006390752406763491
# ...manual computation with logistic function gives: [0.00639075]
#
# p+ at known steady state for M, df1: 0.005121352336800069
# ...manual computation with logistic function gives: [0.00512135]
#
#
# Coefficients of df 2 (F/M): [-0.03463221] / [0.06537594]
# Intercept of df 2 (F/M): [-4.88967464] / [-6.63757588]
# p+ at known steady state for F, df2: 0.0043044594838036005
# ...manual computation with logistic function gives: [0.00430446]
#
# p+ at known steady state for M, df2: 0.0037153475358779205
# ...manual computation with logistic function gives: [0.00371535]
#
#
# Coefficients of df 3 (F/M): [0.02938745] / [0.0596904]
# Intercept of df 3 (F/M): [-5.69685043] / [-6.37961958]
# p+ at known steady state for F, df3: 0.005342784509158928
# ...manual computation with logistic function gives: [0.00534278]
#
# p+ at known steady state for M, df3: 0.004387610484677335
# ...manual computation with logistic function gives: [0.00438761]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 1
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 3, p- all ~= 0.003
# k5 div count: 21, p- all ~= 0.0042
# k10 div count: 48, p- all ~= 0.0048
# k25 div count: 120, p- all ~= 0.0048
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.09611913] / [0.10395975]
# Intercept of df 0 (F/M): [-4.08591574] / [-7.95327919]
# p+ at known steady state for F, df0: 0.0035978238052385906
# ...manual computation with logistic function gives: [0.00359782]
#
# p+ at known steady state for M, df0: 0.0018514680200677266
# ...manual computation with logistic function gives: [0.00185147]
#
#
# Coefficients of df 1 (F/M): [0.04316078] / [0.05987906]
# Intercept of df 1 (F/M): [-6.43139119] / [-6.24515439]
# p+ at known steady state for F, df1: 0.00320185273695394
# ...manual computation with logistic function gives: [0.00320185]
#
# p+ at known steady state for M, df1: 0.005031016831264527
# ...manual computation with logistic function gives: [0.00503102]
#
#
# Coefficients of df 2 (F/M): [-0.1160918] / [-0.03288749]
# Intercept of df 2 (F/M): [-3.65883743] / [-4.77276302]
# p+ at known steady state for F, df2: 0.004004570749172801
# ...manual computation with logistic function gives: [0.00400457]
#
# p+ at known steady state for M, df2: 0.004971930231885452
# ...manual computation with logistic function gives: [0.00497193]
#
#
# Coefficients of df 3 (F/M): [-0.01001659] / [-0.00868961]
# Intercept of df 3 (F/M): [-5.28121736] / [-5.10058015]
# p+ at known steady state for F, df3: 0.004314358960055766
# ...manual computation with logistic function gives: [0.00431436]
#
# p+ at known steady state for M, df3: 0.005274337138326207
# ...manual computation with logistic function gives: [0.00527434]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 2
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 4, p- all ~= 0.004
# k5 div count: 30, p- all ~= 0.006
# k10 div count: 53, p- all ~= 0.0053
# k25 div count: 123, p- all ~= 0.00492
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.1513701] / [0.03223209]
# Intercept of df 0 (F/M): [-3.28598525] / [-6.04518858]
# p+ at known steady state for F, df0: 0.0033086301310782072
# ...manual computation with logistic function gives: [0.00330863]
#
# p+ at known steady state for M, df0: 0.003952387597653067
# ...manual computation with logistic function gives: [0.00395239]
#
#
# Coefficients of df 1 (F/M): [0.01119498] / [0.03455813]
# Intercept of df 1 (F/M): [-5.0059905] / [-6.07194831]
# p+ at known steady state for F, df1: 0.007947876310321402
# ...manual computation with logistic function gives: [0.00794788]
#
# p+ at known steady state for M, df1: 0.003993768492729299
# ...manual computation with logistic function gives: [0.00399377]
#
#
# Coefficients of df 2 (F/M): [-0.02536808] / [-0.00764067]
# Intercept of df 2 (F/M): [-4.86648668] / [-5.084288]
# p+ at known steady state for F, df2: 0.0051052070927060066
# ...manual computation with logistic function gives: [0.00510521]
#
# p+ at known steady state for M, df2: 0.0054507371460242125
# ...manual computation with logistic function gives: [0.00545074]
#
#
# Coefficients of df 3 (F/M): [0.00071107] / [-0.05131695]
# Intercept of df 3 (F/M): [-5.35575056] / [-4.48118063]
# p+ at known steady state for F, df3: 0.004752249949721865
# ...manual computation with logistic function gives: [0.00475225]
#
# p+ at known steady state for M, df3: 0.00495568490737212
# ...manual computation with logistic function gives: [0.00495568]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 3
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 8, p- all ~= 0.008
# k5 div count: 31, p- all ~= 0.0062
# k10 div count: 55, p- all ~= 0.0055
# k25 div count: 143, p- all ~= 0.00572
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.11445663] / [0.17190324]
# Intercept of df 0 (F/M): [-6.74297085] / [-7.82427923]
# p+ at known steady state for F, df0: 0.0073064484423528454
# ...manual computation with logistic function gives: [0.00730645]
#
# p+ at known steady state for M, df0: 0.006219496305603371
# ...manual computation with logistic function gives: [0.0062195]
#
#
# Coefficients of df 1 (F/M): [-0.01512791] / [0.06068055]
# Intercept of df 1 (F/M): [-4.73879106] / [-6.1886957]
# p+ at known steady state for F, df1: 0.006821455440860349
# ...manual computation with logistic function gives: [0.00682146]
#
# p+ at known steady state for M, df1: 0.005389991262564902
# ...manual computation with logistic function gives: [0.00538999]
#
#
# Coefficients of df 2 (F/M): [-0.022954] / [0.02162045]
# Intercept of df 2 (F/M): [-4.72813531] / [-5.68783795]
# p+ at known steady state for F, df2: 0.006087574884217211
# ...manual computation with logistic function gives: [0.00608757]
#
# p+ at known steady state for M, df2: 0.004763912030418686
# ...manual computation with logistic function gives: [0.00476391]
#
#
# Coefficients of df 3 (F/M): [-0.01217903] / [-0.06342671]
# Intercept of df 3 (F/M): [-4.93534565] / [-4.21170927]
# p+ at known steady state for F, df3: 0.0058805320589035955
# ...manual computation with logistic function gives: [0.00588053]
#
# p+ at known steady state for M, df3: 0.005343393452605291
# ...manual computation with logistic function gives: [0.00534339]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 4
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 8, p- all ~= 0.008
# k5 div count: 27, p- all ~= 0.0054
# k10 div count: 43, p- all ~= 0.0043
# k25 div count: 118, p- all ~= 0.00472
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.05845046] / [0.05500869]
# Intercept of df 0 (F/M): [-5.26335541] / [-5.20749393]
# p+ at known steady state for F, df0: 0.002028227561697191
# ...manual computation with logistic function gives: [0.00202823]
#
# p+ at known steady state for M, df0: 0.013030389890771044
# ...manual computation with logistic function gives: [0.01303039]
#
#
# Coefficients of df 1 (F/M): [0.06536802] / [-0.02266925]
# Intercept of df 1 (F/M): [-6.31901813] / [-4.84183133]
# p+ at known steady state for F, df1: 0.0051013798321630725
# ...manual computation with logistic function gives: [0.00510138]
#
# p+ at known steady state for M, df1: 0.005461587115411811
# ...manual computation with logistic function gives: [0.00546159]
#
#
# Coefficients of df 2 (F/M): [0.03277952] / [-0.05824081]
# Intercept of df 2 (F/M): [-5.90477529] / [-4.62767392]
# p+ at known steady state for F, df2: 0.004585304567880572
# ...manual computation with logistic function gives: [0.0045853]
#
# p+ at known steady state for M, df2: 0.0038358273404147723
# ...manual computation with logistic function gives: [0.00383583]
#
#
# Coefficients of df 3 (F/M): [0.01603637] / [-0.07296365]
# Intercept of df 3 (F/M): [-5.57092703] / [-4.28073188]
# p+ at known steady state for F, df3: 0.004896407588208271
# ...manual computation with logistic function gives: [0.00489641]
#
# p+ at known steady state for M, df3: 0.004285812068807928
# ...manual computation with logistic function gives: [0.00428581]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 5
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 8, p- all ~= 0.008
# k5 div count: 20, p- all ~= 0.004
# k10 div count: 38, p- all ~= 0.0038
# k25 div count: 155, p- all ~= 0.0062
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.04969117] / [0.16343553]
# Intercept of df 0 (F/M): [-5.18601377] / [-8.3735983]
# p+ at known steady state for F, df0: 0.01223728440671644
# ...manual computation with logistic function gives: [0.01223728]
#
# p+ at known steady state for M, df0: 0.0031455069486894787
# ...manual computation with logistic function gives: [0.00314551]
#
#
# Coefficients of df 1 (F/M): [0.02660772] / [-0.09473153]
# Intercept of df 1 (F/M): [-5.77830961] / [-4.29650129]
# p+ at known steady state for F, df1: 0.004713564466272646
# ...manual computation with logistic function gives: [0.00471356]
#
# p+ at known steady state for M, df1: 0.00298190745487872
# ...manual computation with logistic function gives: [0.00298191]
#
#
# Coefficients of df 2 (F/M): [-0.04457641] / [0.09603345]
# Intercept of df 2 (F/M): [-4.81233937] / [-7.22573085]
# p+ at known steady state for F, df2: 0.003967823210287438
# ...manual computation with logistic function gives: [0.00396782]
#
# p+ at known steady state for M, df2: 0.003370910749481134
# ...manual computation with logistic function gives: [0.00337091]
#
#
# Coefficients of df 3 (F/M): [0.02316605] / [0.02358282]
# Intercept of df 3 (F/M): [-5.5735322] / [-5.34860862]
# p+ at known steady state for F, df3: 0.005470632804114411
# ...manual computation with logistic function gives: [0.00547063]
#
# p+ at known steady state for M, df3: 0.006886490043652937
# ...manual computation with logistic function gives: [0.00688649]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 6
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 5, p- all ~= 0.005
# k5 div count: 23, p- all ~= 0.0046
# k10 div count: 49, p- all ~= 0.0049
# k25 div count: 143, p- all ~= 0.00572
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.14774314] / [-0.28723166]
# Intercept of df 0 (F/M): [-8.06466696] / [-1.27605443]
# p+ at known steady state for F, df0: 0.003332226947779409
# ...manual computation with logistic function gives: [0.00333223]
#
# p+ at known steady state for M, df0: 0.0028099885110956556
# ...manual computation with logistic function gives: [0.00280999]
#
#
# Coefficients of df 1 (F/M): [0.06215473] / [-0.05741408]
# Intercept of df 1 (F/M): [-7.059745] / [-4.09912338]
# p+ at known steady state for F, df1: 0.0023167528864314105
# ...manual computation with logistic function gives: [0.00231675]
#
# p+ at known steady state for M, df1: 0.006575883826093958
# ...manual computation with logistic function gives: [0.00657588]
#
#
# Coefficients of df 2 (F/M): [-0.10066979] / [-0.03336754]
# Intercept of df 2 (F/M): [-3.63657693] / [-4.98280136]
# p+ at known steady state for F, df2: 0.00523419900289344
# ...manual computation with logistic function gives: [0.0052342]
#
# p+ at known steady state for M, df2: 0.0040030725528183
# ...manual computation with logistic function gives: [0.00400307]
#
#
# Coefficients of df 3 (F/M): [0.01380086] / [-0.02847198]
# Intercept of df 3 (F/M): [-5.25929801] / [-4.84342446]
# p+ at known steady state for F, df3: 0.006441802259416303
# ...manual computation with logistic function gives: [0.0064418]
#
# p+ at known steady state for M, df3: 0.004971864107005437
# ...manual computation with logistic function gives: [0.00497186]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 7
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 3, p- all ~= 0.003
# k5 div count: 28, p- all ~= 0.0056
# k10 div count: 33, p- all ~= 0.0033
# k25 div count: 117, p- all ~= 0.00468
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.2398329] / [0.08677371]
# Intercept of df 0 (F/M): [-2.89128974] / [-6.95197173]
# p+ at known steady state for F, df0: 0.00119475808148399
# ...manual computation with logistic function gives: [0.00119476]
#
# p+ at known steady state for M, df0: 0.0038203240074253133
# ...manual computation with logistic function gives: [0.00382032]
#
#
# Coefficients of df 1 (F/M): [0.04531573] / [0.04630995]
# Intercept of df 1 (F/M): [-5.99996374] / [-5.85343568]
# p+ at known steady state for F, df1: 0.0050923422513371175
# ...manual computation with logistic function gives: [0.00509234]
#
# p+ at known steady state for M, df1: 0.005985115614252979
# ...manual computation with logistic function gives: [0.00598512]
#
#
# Coefficients of df 2 (F/M): [-0.04642655] / [-0.10808025]
# Intercept of df 2 (F/M): [-4.96141398] / [-4.12313221]
# p+ at known steady state for F, df2: 0.0033207487783795185
# ...manual computation with logistic function gives: [0.00332075]
#
# p+ at known steady state for M, df2: 0.0028647189932216855
# ...manual computation with logistic function gives: [0.00286472]
#
#
# Coefficients of df 3 (F/M): [-0.02844] / [0.01130518]
# Intercept of df 3 (F/M): [-4.98734677] / [-5.48117543]
# p+ at known steady state for F, df3: 0.004310477945381391
# ...manual computation with logistic function gives: [0.00431048]
#
# p+ at known steady state for M, df3: 0.004965355754022362
# ...manual computation with logistic function gives: [0.00496536]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 8
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 4, p- all ~= 0.004
# k5 div count: 9, p- all ~= 0.0018
# k10 div count: 45, p- all ~= 0.0045
# k25 div count: 122, p- all ~= 0.00488
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.19157321] / [0.10889417]
# Intercept of df 0 (F/M): [-2.80378672] / [-7.22282934]
# p+ at known steady state for F, df0: 0.002817853537466194
# ...manual computation with logistic function gives: [0.00281785]
#
# p+ at known steady state for M, df0: 0.00414985830059032
# ...manual computation with logistic function gives: [0.00414986]
#
#
# Coefficients of df 1 (F/M): [-0.09662154] / [0.22971647]
# Intercept of df 1 (F/M): [-4.5445439] / [-10.83826938]
# p+ at known steady state for F, df1: 0.002259186803896245
# ...manual computation with logistic function gives: [0.00225919]
#
# p+ at known steady state for M, df1: 0.0007742773302176951
# ...manual computation with logistic function gives: [0.00077428]
#
#
# Coefficients of df 2 (F/M): [0.00953033] / [-0.10101625]
# Intercept of df 2 (F/M): [-5.56579134] / [-3.86911207]
# p+ at known steady state for F, df2: 0.004437105293661594
# ...manual computation with logistic function gives: [0.00443711]
#
# p+ at known steady state for M, df2: 0.004129865547853665
# ...manual computation with logistic function gives: [0.00412987]
#
#
# Coefficients of df 3 (F/M): [0.00553641] / [-0.00243193]
# Intercept of df 3 (F/M): [-5.47617998] / [-5.21289305]
# p+ at known steady state for F, df3: 0.004552130609015946
# ...manual computation with logistic function gives: [0.00455213]
#
# p+ at known steady state for M, df3: 0.005210766334348792
# ...manual computation with logistic function gives: [0.00521077]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 10
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 2, p- all ~= 0.002
# k5 div count: 28, p- all ~= 0.0056
# k10 div count: 41, p- all ~= 0.0041
# k25 div count: 127, p- all ~= 0.00508
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.18981665] / [-0.24743137]
# Intercept of df 0 (F/M): [-9.46214076] / [-2.7741141]
# p+ at known steady state for F, df0: 0.0016177913148549526
# ...manual computation with logistic function gives: [0.00161779]
#
# p+ at known steady state for M, df0: 0.0011895190719678622
# ...manual computation with logistic function gives: [0.00118952]
#
#
# Coefficients of df 1 (F/M): [0.00215226] / [-0.00131382]
# Intercept of df 1 (F/M): [-4.94659536] / [-5.50938252]
# p+ at known steady state for F, df1: 0.007302862711160745
# ...manual computation with logistic function gives: [0.00730286]
#
# p+ at known steady state for M, df1: 0.003948734240724127
# ...manual computation with logistic function gives: [0.00394873]
#
#
# Coefficients of df 2 (F/M): [-0.0697585] / [-0.04919645]
# Intercept of df 2 (F/M): [-4.39477336] / [-4.76076762]
# p+ at known steady state for F, df2: 0.004026154456894791
# ...manual computation with logistic function gives: [0.00402615]
#
# p+ at known steady state for M, df2: 0.003880470376919624
# ...manual computation with logistic function gives: [0.00388047]
#
#
# Coefficients of df 3 (F/M): [-0.00894744] / [0.03728804]
# Intercept of df 3 (F/M): [-5.21395466] / [-5.80849526]
# p+ at known steady state for F, df3: 0.004692371678458064
# ...manual computation with logistic function gives: [0.00469237]
#
# p+ at known steady state for M, df3: 0.005421823059101258
# ...manual computation with logistic function gives: [0.00542182]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 13
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 14, p- all ~= 0.014
# k5 div count: 29, p- all ~= 0.0058
# k10 div count: 44, p- all ~= 0.0044
# k25 div count: 107, p- all ~= 0.00428
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.07058572] / [0.03534658]
# Intercept of df 0 (F/M): [-3.16708839] / [-4.82891347]
# p+ at known steady state for F, df0: 0.013433754712526044
# ...manual computation with logistic function gives: [0.01343375]
#
# p+ at known steady state for M, df0: 0.013879465226955644
# ...manual computation with logistic function gives: [0.01387947]
#
#
# Coefficients of df 1 (F/M): [0.04232992] / [0.03435952]
# Intercept of df 1 (F/M): [-5.75524605] / [-5.79117074]
# p+ at known steady state for F, df1: 0.006193960669517802
# ...manual computation with logistic function gives: [0.00619396]
#
# p+ at known steady state for M, df1: 0.005264878411159013
# ...manual computation with logistic function gives: [0.00526488]
#
#
# Coefficients of df 2 (F/M): [0.04177494] / [0.02649871]
# Intercept of df 2 (F/M): [-6.21093619] / [-5.74896357]
# p+ at known steady state for F, df2: 0.0039012972760950697
# ...manual computation with logistic function gives: [0.0039013]
#
# p+ at known steady state for M, df2: 0.004844841429279251
# ...manual computation with logistic function gives: [0.00484484]
#
#
# Coefficients of df 3 (F/M): [-0.0534999] / [0.01511156]
# Intercept of df 3 (F/M): [-4.65760567] / [-5.6550643]
# p+ at known steady state for F, df3: 0.004015362863852245
# ...manual computation with logistic function gives: [0.00401536]
#
# p+ at known steady state for M, df3: 0.0044372232547134705
# ...manual computation with logistic function gives: [0.00443722]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 14
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 5, p- all ~= 0.005
# k5 div count: 16, p- all ~= 0.0032
# k10 div count: 48, p- all ~= 0.0048
# k25 div count: 113, p- all ~= 0.00452
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.22925534] / [-0.03497735]
# Intercept of df 0 (F/M): [-8.96442595] / [-5.67558241]
# p+ at known steady state for F, df0: 0.004984919791921857
# ...manual computation with logistic function gives: [0.00498492]
#
# p+ at known steady state for M, df0: 0.00195536732159868
# ...manual computation with logistic function gives: [0.00195537]
#
#
# Coefficients of df 1 (F/M): [-0.09698035] / [0.01771191]
# Intercept of df 1 (F/M): [-4.24045615] / [-6.05240564]
# p+ at known steady state for F, df1: 0.003042156959286296
# ...manual computation with logistic function gives: [0.00304216]
#
# p+ at known steady state for M, df1: 0.003113110109812958
# ...manual computation with logistic function gives: [0.00311311]
#
#
# Coefficients of df 2 (F/M): [0.0203548] / [0.11098352]
# Intercept of df 2 (F/M): [-5.85356179] / [-7.04753358]
# p+ at known steady state for F, df2: 0.003958652796428706
# ...manual computation with logistic function gives: [0.00395865]
#
# p+ at known steady state for M, df2: 0.005108147272735971
# ...manual computation with logistic function gives: [0.00510815]
#
#
# Coefficients of df 3 (F/M): [0.01744488] / [0.02347965]
# Intercept of df 3 (F/M): [-5.71039815] / [-5.73936763]
# p+ at known steady state for F, df3: 0.004358409827937167
# ...manual computation with logistic function gives: [0.00435841]
#
# p+ at known steady state for M, df3: 0.0046617428545836035
# ...manual computation with logistic function gives: [0.00466174]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 15
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 6, p- all ~= 0.006
# k5 div count: 13, p- all ~= 0.0026
# k10 div count: 60, p- all ~= 0.006
# k25 div count: 111, p- all ~= 0.00444
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.20649718] / [0.17185737]
# Intercept of df 0 (F/M): [-8.6761679] / [-8.13959617]
# p+ at known steady state for F, df0: 0.004622377697759605
# ...manual computation with logistic function gives: [0.00462238]
#
# p+ at known steady state for M, df0: 0.004541806753955533
# ...manual computation with logistic function gives: [0.00454181]
#
#
# Coefficients of df 1 (F/M): [-0.19920015] / [-0.0997661]
# Intercept of df 1 (F/M): [-3.18574978] / [-4.37216584]
# p+ at known steady state for F, df1: 0.0017042029415519366
# ...manual computation with logistic function gives: [0.0017042]
#
# p+ at known steady state for M, df1: 0.00255174345713227
# ...manual computation with logistic function gives: [0.00255174]
#
#
# Coefficients of df 2 (F/M): [0.01493949] / [0.02390522]
# Intercept of df 2 (F/M): [-5.44131822] / [-5.41412726]
# p+ at known steady state for F, df2: 0.005473837897310757
# ...manual computation with logistic function gives: [0.00547384]
#
# p+ at known steady state for M, df2: 0.006485731446742211
# ...manual computation with logistic function gives: [0.00648573]
#
#
# Coefficients of df 3 (F/M): [-0.01265442] / [-0.02921957]
# Intercept of df 3 (F/M): [-5.27487704] / [-4.89763422]
# p+ at known steady state for F, df3: 0.004162999205272076
# ...manual computation with logistic function gives: [0.004163]
#
# p+ at known steady state for M, df3: 0.004655000936345727
# ...manual computation with logistic function gives: [0.004655]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 16
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 4, p- all ~= 0.004
# k5 div count: 22, p- all ~= 0.0044
# k10 div count: 54, p- all ~= 0.0054
# k25 div count: 118, p- all ~= 0.00472
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.24215019] / [-0.1444197]
# Intercept of df 0 (F/M): [-2.17677015] / [-3.37416917]
# p+ at known steady state for F, df0: 0.0023495638631030697
# ...manual computation with logistic function gives: [0.00234956]
#
# p+ at known steady state for M, df0: 0.003385426069287958
# ...manual computation with logistic function gives: [0.00338543]
#
#
# Coefficients of df 1 (F/M): [-0.04719904] / [0.18983093]
# Intercept of df 1 (F/M): [-4.22385373] / [-9.5613691]
# p+ at known steady state for F, df1: 0.006833655830686892
# ...manual computation with logistic function gives: [0.00683366]
#
# p+ at known steady state for M, df1: 0.0014655262393278505
# ...manual computation with logistic function gives: [0.00146553]
#
#
# Coefficients of df 2 (F/M): [-0.04432366] / [0.03036777]
# Intercept of df 2 (F/M): [-4.48397418] / [-5.74686209]
# p+ at known steady state for F, df2: 0.00552378591604113
# ...manual computation with logistic function gives: [0.00552379]
#
# p+ at known steady state for M, df2: 0.005163427881438416
# ...manual computation with logistic function gives: [0.00516343]
#
#
# Coefficients of df 3 (F/M): [-0.02035025] / [-0.06801484]
# Intercept of df 3 (F/M): [-5.03685364] / [-4.30559369]
# p+ at known steady state for F, df3: 0.004667479484055802
# ...manual computation with logistic function gives: [0.00466748]
#
# p+ at known steady state for M, df3: 0.00452396986382484
# ...manual computation with logistic function gives: [0.00452397]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 17
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 6, p- all ~= 0.006
# k5 div count: 27, p- all ~= 0.0054
# k10 div count: 62, p- all ~= 0.0062
# k25 div count: 106, p- all ~= 0.00424
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.00751695] / [0.05231925]
# Intercept of df 0 (F/M): [-4.95673785] / [-6.00883054]
# p+ at known steady state for F, df0: 0.006199862405539618
# ...manual computation with logistic function gives: [0.00619986]
#
# p+ at known steady state for M, df0: 0.0056427634741898405
# ...manual computation with logistic function gives: [0.00564276]
#
#
# Coefficients of df 1 (F/M): [-0.05650776] / [0.09952559]
# Intercept of df 1 (F/M): [-4.17187937] / [-7.10503704]
# p+ at known steady state for F, df1: 0.006206060353566149
# ...manual computation with logistic function gives: [0.00620606]
#
# p+ at known steady state for M, df1: 0.004019269830263878
# ...manual computation with logistic function gives: [0.00401927]
#
#
# Coefficients of df 2 (F/M): [0.00770164] / [0.01781617]
# Intercept of df 2 (F/M): [-5.07983032] / [-5.49808943]
# p+ at known steady state for F, df2: 0.006987613679830357
# ...manual computation with logistic function gives: [0.00698761]
#
# p+ at known steady state for M, df2: 0.005415656631147273
# ...manual computation with logistic function gives: [0.00541566]
#
#
# Coefficients of df 3 (F/M): [0.01486152] / [-0.03697155]
# Intercept of df 3 (F/M): [-5.66960714] / [-4.90788333]
# p+ at known steady state for F, df3: 0.004356055169966082
# ...manual computation with logistic function gives: [0.00435606]
#
# p+ at known steady state for M, df3: 0.00407245678667031
# ...manual computation with logistic function gives: [0.00407246]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 18
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 7, p- all ~= 0.007
# k5 div count: 15, p- all ~= 0.003
# k10 div count: 47, p- all ~= 0.0047
# k25 div count: 142, p- all ~= 0.00568
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.14050274] / [0.02556241]
# Intercept of df 0 (F/M): [-7.15784279] / [-5.55423133]
# p+ at known steady state for F, df0: 0.007319993309045403
# ...manual computation with logistic function gives: [0.00731999]
#
# p+ at known steady state for M, df0: 0.005793359281760588
# ...manual computation with logistic function gives: [0.00579336]
#
#
# Coefficients of df 1 (F/M): [0.0526056] / [-0.02375497]
# Intercept of df 1 (F/M): [-6.48067187] / [-5.6510451]
# p+ at known steady state for F, df1: 0.0035438823404554155
# ...manual computation with logistic function gives: [0.00354388]
#
# p+ at known steady state for M, df1: 0.002397030644948296
# ...manual computation with logistic function gives: [0.00239703]
#
#
# Coefficients of df 2 (F/M): [0.02599651] / [-0.03242898]
# Intercept of df 2 (F/M): [-5.92780655] / [-4.71516038]
# p+ at known steady state for F, df2: 0.004022334622562004
# ...manual computation with logistic function gives: [0.00402233]
#
# p+ at known steady state for M, df2: 0.005303745996057026
# ...manual computation with logistic function gives: [0.00530375]
#
#
# Coefficients of df 3 (F/M): [-0.0099751] / [0.01446445]
# Intercept of df 3 (F/M): [-5.10248241] / [-5.30900357]
# p+ at known steady state for F, df3: 0.005157748382269397
# ...manual computation with logistic function gives: [0.00515775]
#
# p+ at known steady state for M, df3: 0.00619639268912912
# ...manual computation with logistic function gives: [0.00619639]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 21
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 6, p- all ~= 0.006
# k5 div count: 16, p- all ~= 0.0032
# k10 div count: 55, p- all ~= 0.0055
# k25 div count: 123, p- all ~= 0.00492
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.08208886] / [0.10027283]
# Intercept of df 0 (F/M): [-3.87364577] / [-6.81453221]
# p+ at known steady state for F, df0: 0.005557314614025445
# ...manual computation with logistic function gives: [0.00555731]
#
# p+ at known steady state for M, df0: 0.005431103642341577
# ...manual computation with logistic function gives: [0.0054311]
#
#
# Coefficients of df 1 (F/M): [-0.11823015] / [-0.01101292]
# Intercept of df 1 (F/M): [-3.96016167] / [-5.57960494]
# p+ at known steady state for F, df1: 0.0028663538646568325
# ...manual computation with logistic function gives: [0.00286635]
#
# p+ at known steady state for M, df1: 0.0031543558816520146
# ...manual computation with logistic function gives: [0.00315436]
#
#
# Coefficients of df 2 (F/M): [-0.05209834] / [-0.01178905]
# Intercept of df 2 (F/M): [-4.53209735] / [-4.88829497]
# p+ at known steady state for F, df2: 0.004652575921102495
# ...manual computation with logistic function gives: [0.00465258]
#
# p+ at known steady state for M, df2: 0.006200412663553987
# ...manual computation with logistic function gives: [0.00620041]
#
#
# Coefficients of df 3 (F/M): [0.00181862] / [0.0008711]
# Intercept of df 3 (F/M): [-5.27058362] / [-5.39586215]
# p+ at known steady state for F, df3: 0.0052645264515276645
# ...manual computation with logistic function gives: [0.00526453]
#
# p+ at known steady state for M, df3: 0.004577908816979609
# ...manual computation with logistic function gives: [0.00457791]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 24
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 7, p- all ~= 0.007
# k5 div count: 28, p- all ~= 0.0056
# k10 div count: 54, p- all ~= 0.0054
# k25 div count: 127, p- all ~= 0.00508
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.0334506] / [0.02610882]
# Intercept of df 0 (F/M): [-5.64718497] / [-5.25123154]
# p+ at known steady state for F, df0: 0.005988098227441527
# ...manual computation with logistic function gives: [0.0059881]
#
# p+ at known steady state for M, df0: 0.007895852393414865
# ...manual computation with logistic function gives: [0.00789585]
#
#
# Coefficients of df 1 (F/M): [0.02453627] / [0.00067838]
# Intercept of df 1 (F/M): [-5.44680333] / [-5.34577933]
# p+ at known steady state for F, df1: 0.006341848384060629
# ...manual computation with logistic function gives: [0.00634185]
#
# p+ at known steady state for M, df1: 0.004797147169115447
# ...manual computation with logistic function gives: [0.00479715]
#
#
# Coefficients of df 2 (F/M): [0.00849773] / [0.13341093]
# Intercept of df 2 (F/M): [-5.32250915] / [-7.5236552]
# p+ at known steady state for F, df2: 0.0055601999986954155
# ...manual computation with logistic function gives: [0.0055602]
#
# p+ at known steady state for M, df2: 0.004545415535204531
# ...manual computation with logistic function gives: [0.00454542]
#
#
# Coefficients of df 3 (F/M): [-0.02961584] / [0.00890653]
# Intercept of df 3 (F/M): [-4.8259989] / [-5.40654006]
# p+ at known steady state for F, df3: 0.004967531573339383
# ...manual computation with logistic function gives: [0.00496753]
#
# p+ at known steady state for M, df3: 0.005147744104899379
# ...manual computation with logistic function gives: [0.00514774]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 27
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 2, p- all ~= 0.002
# k5 div count: 21, p- all ~= 0.0042
# k10 div count: 50, p- all ~= 0.005
# k25 div count: 128, p- all ~= 0.00512
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [0.11403177] / [0.10606962]
# Intercept of df 0 (F/M): [-8.10190942] / [-8.0411562]
# p+ at known steady state for F, df0: 0.0018747545200411039
# ...manual computation with logistic function gives: [0.00187475]
#
# p+ at known steady state for M, df0: 0.0017541025652776778
# ...manual computation with logistic function gives: [0.0017541]
#
#
# Coefficients of df 1 (F/M): [-0.11302212] / [-0.03719161]
# Intercept of df 1 (F/M): [-3.71273059] / [-4.94382539]
# p+ at known steady state for F, df1: 0.003985557735829458
# ...manual computation with logistic function gives: [0.00398556]
#
# p+ at known steady state for M, df1: 0.0039154915767291845
# ...manual computation with logistic function gives: [0.00391549]
#
#
# Coefficients of df 2 (F/M): [-0.00998498] / [-0.03424893]
# Intercept of df 2 (F/M): [-5.35081562] / [-4.58234385]
# p+ at known steady state for F, df2: 0.004027494053816017
# ...manual computation with logistic function gives: [0.00402749]
#
# p+ at known steady state for M, df2: 0.005879850135310931
# ...manual computation with logistic function gives: [0.00587985]
#
#
# Coefficients of df 3 (F/M): [-0.05040789] / [-0.00851252]
# Intercept of df 3 (F/M): [-4.53959555] / [-5.08672076]
# p+ at known steady state for F, df3: 0.004743988110249379
# ...manual computation with logistic function gives: [0.00474399]
#
# p+ at known steady state for M, df3: 0.005362644145135333
# ...manual computation with logistic function gives: [0.00536264]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checking seed 28
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 3, p- all ~= 0.003
# k5 div count: 27, p- all ~= 0.0054
# k10 div count: 57, p- all ~= 0.0057
# k25 div count: 116, p- all ~= 0.00464
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.40153007] / [0.00519569]
# Intercept of df 0 (F/M): [-1.06904634] / [-5.58090571]
# p+ at known steady state for F, df0: 0.0005563661191363977
# ...manual computation with logistic function gives: [0.00055637]
#
# p+ at known steady state for M, df0: 0.004079168421813342
# ...manual computation with logistic function gives: [0.00407917]
#
#
# Coefficients of df 1 (F/M): [-0.01244681] / [-0.08705214]
# Intercept of df 1 (F/M): [-4.92870335] / [-3.99841721]
# p+ at known steady state for F, df1: 0.005894331973193141
# ...manual computation with logistic function gives: [0.00589433]
#
# p+ at known steady state for M, df1: 0.00453560219978462
# ...manual computation with logistic function gives: [0.0045356]
#
#
# Coefficients of df 2 (F/M): [-0.00356017] / [-0.06730364]
# Intercept of df 2 (F/M): [-5.15077503] / [-4.0834961]
# p+ at known steady state for F, df2: 0.005444241650990575
# ...manual computation with logistic function gives: [0.00544424]
#
# p+ at known steady state for M, df2: 0.00570690980807042
# ...manual computation with logistic function gives: [0.00570691]
#
#
# Coefficients of df 3 (F/M): [0.02252547] / [-0.02314736]
# Intercept of df 3 (F/M): [-5.82911399] / [-4.91554409]
# p+ at known steady state for F, df3: 0.004198977348577794
# ...manual computation with logistic function gives: [0.00419898]
#
# p+ at known steady state for M, df3: 0.005036965214222161
# ...manual computation with logistic function gives: [0.00503697]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# Checker completed, returning total and frequency of properly signed models per sample size
# (20, [0.05, 0.2, 0.4, 0.25])

# %%
print(post_df)
# Out:
#          Tissue_ID Cell_Type            X            Y  #F_neighbours  \
# 0                0         F  1397.202632   344.460028              0
# 1                0         F  1446.412644  1220.337777              2
# 2                0         F  1725.740985  1286.893035              1
# 3                0         F  1610.214275   846.272191              4
# 4                0         F   383.069894    19.102864              8
# ...            ...       ...          ...          ...            ...
# 9831520         99         F  1616.294539   894.147790             16
# 9831521         99         F  2210.508130   142.295888             11
# 9831522         99         F  1840.527943   230.225746             21
# 9831523         99         M  2203.411952   788.174766             13
# 9831524         99         F  1248.870366  2000.283209              8
#
#          #F_neighbours_log2  #M_neighbours  #M_neighbours_log2  Time_Step
# 0                      -inf             29            4.857981        100
# 1                  1.000000             23            4.523562        100
# 2                  0.000000             26            4.700440        100
# 3                  2.000000             17            4.087463        100
# 4                  3.000000             15            3.906891        100
# ...                     ...            ...                 ...        ...
# 9831520            4.000000             20            4.321928       1000
# 9831521            3.459432             20            4.321928       1000
# 9831522            4.392317             22            4.459432       1000
# 9831523            3.700440             15            3.906891       1000
# 9831524            3.000000             13            3.700440       1000
#
# [9831525 rows x 9 columns]

# %%
post_df["Time_Step"].unique()
# Out:
# array([ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1000])

# %% [markdown]
# ## 7. Visualise fit model against true model over cell neighbourhoods (P+ - P- over Xi).

# %%
display(k1_df)
# Out:
#         Tissue_ID Cell_Type            X            Y  #F_neighbours  \
# 225294         22         M   214.148139   230.572922             16
# 534790         52         F  2420.333159  1139.373397             14
# 411950         40         F  1584.307652  2461.707160             12
# 314845         30         M  2290.075725  1317.149821             11
# 981477         96         M  1715.585859   795.909375             11
# ...           ...       ...          ...          ...            ...
# 589912         57         F  1347.203912   225.984119             14
# 566929         55         F    98.982048   342.153613             19
# 191801         18         M  1505.576045  1606.127320             16
# 249022         24         M  2045.025396   383.315625             17
# 201090         19         F    36.906274  1450.636263             13
#
#         #F_neighbours_log2  #M_neighbours  #M_neighbours_log2
# 225294            4.000000             23            4.523562
# 534790            3.807355             23            4.523562
# 411950            3.584963              9            3.169925
# 314845            3.459432             12            3.584963
# 981477            3.459432              9            3.169925
# ...                    ...            ...                 ...
# 589912            3.807355             21            4.392317
# 566929            4.247928             16            4.000000
# 191801            4.000000             18            4.169925
# 249022            4.087463             11            3.459432
# 201090            3.700440             13            3.700440
#
# [1000 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#set known model parameters
F_a=48*10**-4
F_b=3*10**-4
print(f"F cells expected SS: {F_a/F_b}") #check for float-related errors (e.g. slightly incorrect result)
M_a=48*10**-4
M_b=3*10**-4
print(f"M cells expected SS: {M_a/M_b}")

#define functions to get p+ minus p- for a given neighbourhood state (though in the first case, F and M are independent for simplicity, in the infererences)
def div_death_known(state):
    F, M = state

    pp_f = F_a
    pm_f = F_b*F

    pp_m = M_a
    pm_m = M_b*M

    return [pp_f-pm_f, pp_m-pm_m]

def div_death_inferred(state, params, t_id):
    F, M = state

    z_f = params["pplus_f"][t_id][0] + F*params["pplus_f"][t_id][1]
    pp_f = 1/ (1 + np.exp(-z_f))
    pm_f = params["pminus_f"][t_id]

    z_m = params["pplus_m"][t_id][0] + M*params["pplus_m"][t_id][1]
    pp_m = 1/ (1 + np.exp(-z_m))
    pm_m = params["pminus_m"][t_id]

    return [pp_f-pm_f, pp_m-pm_m]

#main function to compare fit model to known model points from corresponding sampels
def compare_likelihoods(dfs, params, t_id=0):
    #get the chosen dataframe and separate F and M cell rows
    df=dfs[t_id]
    df_F=df.loc[df["Cell_Type"]=="F"]
    df_M=df.loc[df["Cell_Type"]=="M"]

    #counts of cell X in cell X's neighbourhood
    F_known=[]
    F_infer=[]

    M_known=[]
    M_infer=[]

    #likewise, but p+ minus p-
    divdeath_kf=[]
    divdeath_if=[]

    divdeath_km=[]
    divdeath_im=[]

    #fill known lists, F models then M models
    for i in range(len(df_F)):
        cell=df_F.iloc[i]
        count=int(cell["#F_neighbours"])
        F_known.append(count)
        divdeath_kf.append(div_death_known([count,count])[0])

    for i in range(len(df_M)):
        cell=df_M.iloc[i]
        count=int(cell["#M_neighbours"])
        M_known.append(count)
        divdeath_km.append(div_death_known([count,count])[1])

    #same with lists for inferred data
    for i in range(max(F_known)+10):
        F_infer.append(i)
        divdeath_if.append(div_death_inferred([i,i],params,t_id)[0])
    
    for i in range(max(M_known)+10):
        M_infer.append(i)
        divdeath_im.append(div_death_inferred([i,i],params,t_id)[1])
    
    #plotting 
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

    # First plot using Seaborn
    #ax1.scatter(F_known, divdeath_kf, color='blue', marker='o', label='Known data')
    ax1.hexbin(F_known, divdeath_kf, gridsize=40, cmap='Blues', mincnt=1, alpha=1)
    ax1.plot(F_infer, divdeath_if, color='orange', linestyle='-', label='Inferred model')
    ax1.set_title('F models')
    ax1.set_xlabel('F')
    ax1.set_ylabel('Proliferation')
    ax1.legend()

    # Second plot using Seaborn
    #ax2.scatter(M_known, divdeath_km, color='green', marker='s', label='Known data')
    ax2.hexbin(M_known, divdeath_km, gridsize=40, cmap='Greens', mincnt=1, alpha=1)
    ax2.plot(M_infer, divdeath_im, color='purple', linestyle='-', label='Inferred model')
    ax2.set_title('M models')
    ax2.set_xlabel('M')
    ax2.set_ylabel('Proliferation')
    ax2.legend()
 

    # Global title
    fig.suptitle(f'Known vs Inference | p+ minus p- | df {t_id}', fontsize=16)

    # Display plots
    plt.tight_layout()
    plt.show()
# Out:
# F cells expected SS: 16.0
# M cells expected SS: 16.0

# %%
#load samples
main_sample, k1_df, k5_df, k10_df, k25_df  = cell_sampler(post_df)
dfs={0:k1_df, 1:k5_df, 2:k10_df, 3:k25_df}

#load inferred parameters
pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df)
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

#first dataset (with only the final tissue state at t=1000)
for i in range(0,4):
    compare_likelihoods(dfs, params, t_id=i)

# %%
for t in post_df["Time_Step"].unique():
    print(f"t={int(t)}")
    # second dataset, loop through time steps
    #load samples
    main_sample, k1_df, k5_df, k10_df, k25_df  = cell_sampler(post_df, int(t), seed=1)
    dfs={0:k1_df, 1:k5_df, 2:k10_df, 3:k25_df}

    #load inferred parameters
    pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, int(t), seed=1)
    params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

    #first dataset (with only the final tissue state at t=1000)
    for i in range(0,4):
        compare_likelihoods(dfs, params, t_id=i)

# %% [markdown]
# ## 8. Visualise Logistic Fits

# %%
# Visualising logistic fits

import seaborn as sns
import matplotlib.pyplot as plt


#set known model parameters
F_a=48*10**-4
F_b=3*10**-4
print(f"F cells expected SS: {F_a/F_b}") #check for float-related errors (e.g. slightly incorrect result)
M_a=48*10**-4
M_b=3*10**-4
print(f"M cells expected SS: {M_a/M_b}")

#define functions to get p+ minus p- for a given neighbourhood state (though in the first case, F and M are independent for simplicity, in the infererences)

def logistic_p(type, count, params, t_id):

    z = params[f"pplus_{type}"][t_id][0] + count*params[f"pplus_{type}"][t_id][1]
    pp = 1/ (1 + np.exp(-z))

    return pp

#main function to compare fit model to known model points from corresponding sampels
def visualise_logfit(dfs, params, t_id=0):
    #get the chosen dataframe and separate F and M cell rows
    df=dfs[t_id].copy()
    df["Division_Observation"]=y_dict[t_id]
    
    df_F=df.loc[df["Cell_Type"]=="F"].copy()
    df_M=df.loc[df["Cell_Type"]=="M"].copy()

    #likewise, but p+ of the inferred model
    df_F['Division_Probability'] = df_F['#F_neighbours'].apply(lambda x: logistic_p("f",x, params, t_id))
    df_M['Division_Probability'] = df_M['#M_neighbours'].apply(lambda x: logistic_p("m",x, params, t_id))

    print(f"P+ at 4 #F:\t{logistic_p("f",4, params, t_id)}\nP+ at 16#F:\t{logistic_p("f",16, params, t_id)}\nP+ at 28#f:\t{logistic_p("f",28, params, t_id)}")
    #plotting 
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

    # First plot using Seaborn
    ax1.scatter(df_F["#F_neighbours"], df_F["Division_Observation"], color='orange', marker='o', label='Observations')
    ax1.plot(df_F["#F_neighbours"], df_F["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    ax1.set_title('F model')
    ax1.set_xlabel('F')
    ax1.set_ylabel('Division')
    ax1.legend()

    # Second plot using Seaborn
    ax2.scatter(df_M["#M_neighbours"], df_M["Division_Observation"], color='orange', marker='o', label='Observations')
    ax2.plot(df_M["#M_neighbours"], df_M["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    ax2.set_title('M model')
    ax2.set_xlabel('M')
    ax2.set_ylabel('Division')
    ax2.legend()
 

    # Global title
    fig.suptitle(f'OSDR Logistic fit | df {t_id}', fontsize=16)

    # Display plots
    plt.tight_layout()
    plt.show()
# Out:
# F cells expected SS: 16.0
# M cells expected SS: 16.0

# %%
#hexbin experimentation
# Visualising logistic fits

import seaborn as sns
import matplotlib.pyplot as plt


#parameters, the same for both cell types, would require a type-specific parameter set when going for less simple models
a, intercept = -0.120, -2.456
b = 1 / (1+np.exp(-(intercept+a*16)))

#define functions to get p+ minus p- for a given neighbourhood state (though in the first case, F and M are independent for simplicity, in the infererences)

def logistic_p(type, count, params, t_id):

    z = params[f"pplus_{type}"][t_id][0] + count*params[f"pplus_{type}"][t_id][1]
    pp = 1/ (1 + np.exp(-z))

    return pp

#main function to compare fit model to known model points from corresponding sampels
def visualise_logfit(dfs, params, t_id=0):
    #get the chosen dataframe and separate F and M cell rows
    df=dfs[t_id].copy()
    df["Division_Observation"]=y_dict[t_id]
    
    df_F=df.loc[df["Cell_Type"]=="F"].copy()
    df_M=df.loc[df["Cell_Type"]=="M"].copy()

    #likewise, but p+ of the inferred model
    df_F['Division_Probability'] = df_F['#F_neighbours'].apply(lambda x: logistic_p("f",x, params, t_id))
    df_M['Division_Probability'] = df_M['#M_neighbours'].apply(lambda x: logistic_p("m",x, params, t_id))
    print(min(df_F['Division_Probability']),max(df_F['Division_Probability']))
    print(min(df_M['Division_Probability']),max(df_M['Division_Probability']))
    print(f"P+ at 4 #F:\t{logistic_p("f",4, params, t_id)}\nP+ at 16#F:\t{logistic_p("f",16, params, t_id)}\nP+ at 28#f:\t{logistic_p("f",28, params, t_id)}")
    #plotting 
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

    # First plot using Seaborn
    ax1.hexbin(df_F["#F_neighbours"], df_F["Division_Observation"], gridsize=40, cmap='magma', mincnt=1, alpha=1, label='Observations')
    #ax1.plot(df_F["#F_neighbours"], df_F["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    
    # Create the second axis for the regression
    ax1b = ax1.twinx()
    ax1b.scatter(df_F["#F_neighbours"], df_F["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    ax1b.set_ylabel('Logistic regression')
    ax1b.tick_params(axis='y', labelcolor='r')
    ax1b.set_ylim(min(df_F['Division_Probability']),max(df_F['Division_Probability']))
    
    ax1.set_title('F model')
    ax1.set_xlabel('F')
    ax1.set_ylabel('Division observation')
    #ax1.legend()

    # Second plot using Seaborn
    ax2.hexbin(df_M["#M_neighbours"], df_M["Division_Observation"], gridsize=40, cmap='inferno', mincnt=1, alpha=1, label='Observations')
    #ax2.plot(df_M["#M_neighbours"], df_M["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    
    # Create the second axis for the regression
    ax2b = ax2.twinx()
    ax2b.scatter(df_M["#M_neighbours"], df_M["Division_Probability"], color='blue', linestyle='-', label='Inferred probabilities')
    ax2b.set_ylabel('Logistic regression')
    ax2b.tick_params(axis='y', labelcolor='r')
    ax2b.set_ylim(min(df_M['Division_Probability']),max(df_M['Division_Probability']))

    ax2.set_title('M model')
    ax2.set_xlabel('M')
    ax2.set_ylabel('Division')
    #ax2.legend()
 

    # Global title
    fig.suptitle(f'OSDR Logistic fit | df {t_id}', fontsize=16)

    # Display plots
    plt.tight_layout()
    plt.show()

# %%
#load samples
main_sample, k1_df, k5_df, k10_df, k25_df  = cell_sampler(post_df, 1000, seed=1)
dfs={0:k1_df, 1:k5_df, 2:k10_df, 3:k25_df}

#load inferred parameters
pplus_f, pplus_m, pminus_f, pminus_m = tissue_regression(post_df, 1000, seed=1, broadcast=True)
params={"pplus_f":pplus_f, "pplus_m":pplus_m, "pminus_f":pminus_f, "pminus_m":pminus_m}

#first dataset (with only the final tissue state at t=1000)
for i in range(0,4):
    visualise_logfit(dfs, params, t_id=i)
# Out:
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
#
# Cell Sampler : Now processing data at t=1000.
#
# Done sampling cell data. 50000 cells sampled.
# Done choosing sampled cells for child dataframes.
# Child 1: 1000 cells.
# Child 2: 5000 cells.
# Child 3: 10000 cells.
# Child 4: 25000 cells.
# Done generating child dataframes.
# Completed generation of label y dictionary, with 4 lists stored.
# k1 div count: 3, p- all ~= 0.003
# k5 div count: 21, p- all ~= 0.0042
# k10 div count: 48, p- all ~= 0.0048
# k25 div count: 120, p- all ~= 0.0048
#
# #####INFERENCE#####
# Coefficients of df 0 (F/M): [-0.09611913] / [0.10395975]
# Intercept of df 0 (F/M): [-4.08591574] / [-7.95327919]
# p+ at known steady state for F, df0: 0.0035978238052385906
# ...manual computation with logistic function gives: [0.00359782]
#
# p+ at known steady state for M, df0: 0.0018514680200677266
# ...manual computation with logistic function gives: [0.00185147]
#
#
# Coefficients of df 1 (F/M): [0.04316078] / [0.05987906]
# Intercept of df 1 (F/M): [-6.43139119] / [-6.24515439]
# p+ at known steady state for F, df1: 0.00320185273695394
# ...manual computation with logistic function gives: [0.00320185]
#
# p+ at known steady state for M, df1: 0.005031016831264527
# ...manual computation with logistic function gives: [0.00503102]
#
#
# Coefficients of df 2 (F/M): [-0.1160918] / [-0.03288749]
# Intercept of df 2 (F/M): [-3.65883743] / [-4.77276302]
# p+ at known steady state for F, df2: 0.004004570749172801
# ...manual computation with logistic function gives: [0.00400457]
#
# p+ at known steady state for M, df2: 0.004971930231885452
# ...manual computation with logistic function gives: [0.00497193]
#
#
# Coefficients of df 3 (F/M): [-0.01001659] / [-0.00868961]
# Intercept of df 3 (F/M): [-5.28121736] / [-5.10058015]
# p+ at known steady state for F, df3: 0.004314358960055766
# ...manual computation with logistic function gives: [0.00431436]
#
# p+ at known steady state for M, df3: 0.005274337138326207
# ...manual computation with logistic function gives: [0.00527434]
#
#
#
#
# Returning parameter dictionaries pplus_f, pplus_m, pminus_f, pminus_m. Each corresponds to the dataset of origin, e.g. 0 for 1K cells sample, 1 for 5k
# 0.0005278320820707106 0.013678541951964239
# 0.0005324759515337843 0.007114739149642454
# P+ at 4 #F:	0.011313369512712232
# P+ at 16#F:	0.0035978238052385906
# P+ at 28#f:	0.0011381056571565854
# 0.0018294498855857713 0.006366958102337759
# 0.002458755539811417 0.014639757053073806
# P+ at 4 #F:	0.0019099850394960105
# P+ at 16#F:	0.00320185273695394
# P+ at 28#f:	0.005362813577944448
# 0.0005584053185778676 0.02001567161260163
# 0.0029436335399424837 0.007856410691442517
# P+ at 4 #F:	0.015934519625108716
# P+ at 16#F:	0.004004570749172801
# P+ at 28#f:	0.0009973530312464582
# 0.00364130608576475 0.004960625102062048
# 0.004514091462150251 0.005952584723705024
# P+ at 4 #F:	0.004862715228423378
# P+ at 16#F:	0.004314358960055766
# P+ at 28#f:	0.0038276016173550012
