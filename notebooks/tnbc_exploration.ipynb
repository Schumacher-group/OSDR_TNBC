# %%
#imports
import numpy as np
import pandas as pd

# %%
#load data, takes about a minute
tncb_df=pd.read_csv("../data/cell_table_bothneighbourhoods.csv")

# %%
pd.set_option('display.max_columns', None)
print("The DataFrame head:")
display(tncb_df.head())
print("The DataFrame tail:")
display(tncb_df.tail())
# multiple ways of getting column names as list
print("\nThe column headers :")
print("Column headers from list(df.columns.values):",
      list(tncb_df.columns.values))
# Out:
# The DataFrame head:
#    Unnamed: 0.1  Unnamed: 0  cell_size  Alpha-SMA     B7-H4  Beta-Catenin  \
# 0             0           0       20.0   0.288579  0.223591      0.648155
# 1             1           1       24.0   0.077877  0.593262      0.409555
# 2             2           2        6.0   0.061702  0.975959      0.996395
# 3             3           3       36.0   0.039577  0.251406      0.123735
# 4             4           4       12.0   0.068972  0.873710      0.803824
#
#      CD107a     CD11b      CD14      CD16     CD163      CD20      CD27  \
# 0  0.547847  0.715537  0.440204  0.696713  0.552185  0.595030  0.704277
# 1  0.868981  0.643709  0.884689  0.940595  0.945193  0.794492  0.578968
# 2  0.243078  0.959890  0.642164  0.097872  0.289209  0.678315  0.547897
# 3  0.037603  0.226375  0.232038  0.218022  0.051993  0.483518  0.148140
# 4  0.207794  0.661986  0.328056  0.317853  0.216726  0.643033  0.754493
#
# ...
